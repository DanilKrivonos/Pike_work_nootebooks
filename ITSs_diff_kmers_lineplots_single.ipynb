# %% [markdown]
# **ITSs diff kmers plots**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import random

# %%
data_its1_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_1_data_tax_df_OTU.csv', sep='\t',index_col=0)
data_its1_g = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_1_data_tax_df_genus.csv', sep = '\t', index_col=0)
data_its1_s = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_1_data_tax_df_species.csv', sep = '\t', index_col=0)
data_its2_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_2_data_tax_df_OTU.csv', sep='\t',index_col=0)
data_its2_g = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_2_data_tax_df_genus.csv', sep = '\t', index_col=0)
data_its2_s = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_2_data_tax_df_species.csv', sep = '\t', index_col=0)
data_its12_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_12_data_tax_df_OTU.csv', sep='\t',index_col=0)
data_its12_g = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_12_data_tax_df_genus.csv', sep = '\t', index_col=0)
data_its12_s = pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_tables_single/single_kmers_3_7_ITS_12_data_tax_df_species.csv', sep = '\t', index_col=0)

# %%
data_its12_g
# Out:
#                              ITS1_5.8_ITS2_1_3_kmer_size  \
# g__Dekkeromyces                                 0.000000
# g__Fungi_gen_Incertae_sedis                     0.004618
# g__Kluyveromyces                                0.043710
# g__Meyerozyma                                   0.073014
# g__Rhodotorula                                  0.072008
# g__Pichia                                       0.086690
# g__Clavispora                                   0.114968
# g__Yarrowia                                     0.160434
# g__Candida                                      0.444558
#
#                              ITS1_5.8_ITS2_1_4_kmer_size  \
# g__Dekkeromyces                                 0.000730
# g__Fungi_gen_Incertae_sedis                     0.001322
# g__Kluyveromyces                                0.043269
# g__Meyerozyma                                   0.073121
# g__Rhodotorula                                  0.075469
# ...

# %%
its1_g_k3 = data_its1_g.iloc[:, [0,5,10]].mean(axis=1)
its1_g_k4 = data_its1_g.iloc[:, [1,6,11]].mean(axis=1)
its1_g_k5 = data_its1_g.iloc[:, [2,7,12]].mean(axis=1)
its1_g_k6 = data_its1_g.iloc[:, [3,8,13]].mean(axis=1)
its1_g_k7 = data_its1_g.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its1_g = pd.concat([its1_g_k3,its1_g_k4,its1_g_k5,its1_g_k6,its1_g_k7], axis=1)
its1_g_k3_r = data_its1_g.iloc[:, [15,20,25]].mean(axis=1)
its1_g_k4_r = data_its1_g.iloc[:, [16,21,26]].mean(axis=1)
its1_g_k5_r = data_its1_g.iloc[:, [17,22,27]].mean(axis=1)
its1_g_k6_r = data_its1_g.iloc[:, [18,23,28]].mean(axis=1)
its1_g_k7_r = data_its1_g.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its1_g = pd.concat([its1_g_k3_r,its1_g_k4_r,its1_g_k5_r,its1_g_k6_r,its1_g_k7_r], axis=1)

# %%
its1_s_k3 = data_its1_s.iloc[:, [0,5,10]].mean(axis=1)
its1_s_k4 = data_its1_s.iloc[:, [1,6,11]].mean(axis=1)
its1_s_k5 = data_its1_s.iloc[:, [2,7,12]].mean(axis=1)
its1_s_k6 = data_its1_s.iloc[:, [3,8,13]].mean(axis=1)
its1_s_k7 = data_its1_s.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its1_s = pd.concat([its1_s_k3,its1_s_k4,its1_s_k5,its1_s_k6,its1_s_k7], axis=1)
its1_s_k3_r = data_its1_s.iloc[:, [15,20,25]].mean(axis=1)
its1_s_k4_r = data_its1_s.iloc[:, [16,21,26]].mean(axis=1)
its1_s_k5_r = data_its1_s.iloc[:, [17,22,27]].mean(axis=1)
its1_s_k6_r = data_its1_s.iloc[:, [18,23,28]].mean(axis=1)
its1_s_k7_r = data_its1_s.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its1_s = pd.concat([its1_s_k3_r,its1_s_k4_r,its1_s_k5_r,its1_s_k6_r,its1_s_k7_r], axis=1)

# %%
its1_otu_k3 = data_its1_otu.iloc[:, [0,5,10]].mean(axis=1)
its1_otu_k4 = data_its1_otu.iloc[:, [1,6,11]].mean(axis=1)
its1_otu_k5 = data_its1_otu.iloc[:, [2,7,12]].mean(axis=1)
its1_otu_k6 = data_its1_otu.iloc[:, [3,8,13]].mean(axis=1)
its1_otu_k7 = data_its1_otu.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its1_otu = pd.concat([its1_otu_k3,its1_otu_k4,its1_otu_k5,its1_otu_k6,its1_otu_k7], axis=1)
its1_otu_k3_r = data_its1_otu.iloc[:, [15,20,25]].mean(axis=1)
its1_otu_k4_r = data_its1_otu.iloc[:, [16,21,26]].mean(axis=1)
its1_otu_k5_r = data_its1_otu.iloc[:, [17,22,27]].mean(axis=1)
its1_otu_k6_r = data_its1_otu.iloc[:, [18,23,28]].mean(axis=1)
its1_otu_k7_r = data_its1_otu.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its1_otu = pd.concat([its1_otu_k3_r,its1_otu_k4_r,its1_otu_k5_r,its1_otu_k6_r,its1_otu_k7_r], axis=1)

# %%
its2_g_k3 = data_its2_g.iloc[:, [0,5,10]].mean(axis=1)
its2_g_k4 = data_its2_g.iloc[:, [1,6,11]].mean(axis=1)
its2_g_k5 = data_its2_g.iloc[:, [2,7,12]].mean(axis=1)
its2_g_k6 = data_its2_g.iloc[:, [3,8,13]].mean(axis=1)
its2_g_k7 = data_its2_g.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its2_g = pd.concat([its2_g_k3,its2_g_k4,its2_g_k5,its2_g_k6,its2_g_k7], axis=1)
its2_g_k3_r = data_its2_g.iloc[:, [15,20,25]].mean(axis=1)
its2_g_k4_r = data_its2_g.iloc[:, [16,21,26]].mean(axis=1)
its2_g_k5_r = data_its2_g.iloc[:, [17,22,27]].mean(axis=1)
its2_g_k6_r = data_its2_g.iloc[:, [18,23,28]].mean(axis=1)
its2_g_k7_r = data_its2_g.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its2_g = pd.concat([its2_g_k3_r,its2_g_k4_r,its2_g_k5_r,its2_g_k6_r,its2_g_k7_r], axis=1)

# %%
its2_s_k3 = data_its2_s.iloc[:, [0,5,10]].mean(axis=1)
its2_s_k4 = data_its2_s.iloc[:, [1,6,11]].mean(axis=1)
its2_s_k5 = data_its2_s.iloc[:, [2,7,12]].mean(axis=1)
its2_s_k6 = data_its2_s.iloc[:, [3,8,13]].mean(axis=1)
its2_s_k7 = data_its2_s.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its2_s = pd.concat([its2_s_k3,its2_s_k4,its2_s_k5,its2_s_k6,its2_s_k7], axis=1)
its2_s_k3_r = data_its2_s.iloc[:, [15,20,25]].mean(axis=1)
its2_s_k4_r = data_its2_s.iloc[:, [16,21,26]].mean(axis=1)
its2_s_k5_r = data_its2_s.iloc[:, [17,22,27]].mean(axis=1)
its2_s_k6_r = data_its2_s.iloc[:, [18,23,28]].mean(axis=1)
its2_s_k7_r = data_its2_s.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its2_s = pd.concat([its2_s_k3_r,its2_s_k4_r,its2_s_k5_r,its2_s_k6_r,its2_s_k7_r], axis=1)

# %%
its2_otu_k3 = data_its2_otu.iloc[:, [0,5,10]].mean(axis=1)
its2_otu_k4 = data_its2_otu.iloc[:, [1,6,11]].mean(axis=1)
its2_otu_k5 = data_its2_otu.iloc[:, [2,7,12]].mean(axis=1)
its2_otu_k6 = data_its2_otu.iloc[:, [3,8,13]].mean(axis=1)
its2_otu_k7 = data_its2_otu.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its2_otu = pd.concat([its2_otu_k3,its2_otu_k4,its2_otu_k5,its2_otu_k6,its2_otu_k7], axis=1)
its2_otu_k3_r = data_its2_otu.iloc[:, [15,20,25]].mean(axis=1)
its2_otu_k4_r = data_its2_otu.iloc[:, [16,21,26]].mean(axis=1)
its2_otu_k5_r = data_its2_otu.iloc[:, [17,22,27]].mean(axis=1)
its2_otu_k6_r = data_its2_otu.iloc[:, [18,23,28]].mean(axis=1)
its2_otu_k7_r = data_its2_otu.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its2_otu = pd.concat([its2_otu_k3_r,its2_otu_k4_r,its2_otu_k5_r,its2_otu_k6_r,its2_otu_k7_r], axis=1)

# %%
its12_g_k3 = data_its12_g.iloc[:, [0,5,10]].mean(axis=1)
its12_g_k4 = data_its12_g.iloc[:, [1,6,11]].mean(axis=1)
its12_g_k5 = data_its12_g.iloc[:, [2,7,12]].mean(axis=1)
its12_g_k6 = data_its12_g.iloc[:, [3,8,13]].mean(axis=1)
its12_g_k7 = data_its12_g.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its12_g = pd.concat([its12_g_k3,its12_g_k4,its12_g_k5,its12_g_k6,its12_g_k7], axis=1)
its12_g_k3_r = data_its12_g.iloc[:, [15,20,25]].mean(axis=1)
its12_g_k4_r = data_its12_g.iloc[:, [16,21,26]].mean(axis=1)
its12_g_k5_r = data_its12_g.iloc[:, [17,22,27]].mean(axis=1)
its12_g_k6_r = data_its12_g.iloc[:, [18,23,28]].mean(axis=1)
its12_g_k7_r = data_its12_g.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its12_g = pd.concat([its12_g_k3_r,its12_g_k4_r,its12_g_k5_r,its12_g_k6_r,its12_g_k7_r], axis=1)

# %%
its12_s_k3 = data_its12_s.iloc[:, [0,5,10]].mean(axis=1)
its12_s_k4 = data_its12_s.iloc[:, [1,6,11]].mean(axis=1)
its12_s_k5 = data_its12_s.iloc[:, [2,7,12]].mean(axis=1)
its12_s_k6 = data_its12_s.iloc[:, [3,8,13]].mean(axis=1)
its12_s_k7 = data_its12_s.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its12_s = pd.concat([its12_s_k3,its12_s_k4,its12_s_k5,its12_s_k6,its12_s_k7], axis=1)
its12_s_k3_r = data_its12_s.iloc[:, [15,20,25]].mean(axis=1)
its12_s_k4_r = data_its12_s.iloc[:, [16,21,26]].mean(axis=1)
its12_s_k5_r = data_its12_s.iloc[:, [17,22,27]].mean(axis=1)
its12_s_k6_r = data_its12_s.iloc[:, [18,23,28]].mean(axis=1)
its12_s_k7_r = data_its12_s.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its12_s = pd.concat([its12_s_k3_r,its12_s_k4_r,its12_s_k5_r,its12_s_k6_r,its12_s_k7_r], axis=1)

# %%
its12_otu_k3 = data_its12_otu.iloc[:, [0,5,10]].mean(axis=1)
its12_otu_k4 = data_its12_otu.iloc[:, [1,6,11]].mean(axis=1)
its12_otu_k5 = data_its12_otu.iloc[:, [2,7,12]].mean(axis=1)
its12_otu_k6 = data_its12_otu.iloc[:, [3,8,13]].mean(axis=1)
its12_otu_k7 = data_its12_otu.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_its12_otu = pd.concat([its12_otu_k3,its12_otu_k4,its12_otu_k5,its12_otu_k6,its12_otu_k7], axis=1)
its12_otu_k3_r = data_its12_otu.iloc[:, [15,20,25]].mean(axis=1)
its12_otu_k4_r = data_its12_otu.iloc[:, [16,21,26]].mean(axis=1)
its12_otu_k5_r = data_its12_otu.iloc[:, [17,22,27]].mean(axis=1)
its12_otu_k6_r = data_its12_otu.iloc[:, [18,23,28]].mean(axis=1)
its12_otu_k7_r = data_its12_otu.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_its12_otu = pd.concat([its12_otu_k3_r,its12_otu_k4_r,its12_otu_k5_r,its12_otu_k6_r,its12_otu_k7_r], axis=1)

# %%
def get_color(obj_dict):
    color = ''
    while color not in obj_dict.values() and color == '':
        color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color
color_dict_its1_s = {}
color_dict_its1_otu = {}
color_dict_its2_s = {}
color_dict_its2_otu = {}
color_dict_its12_s = {}
color_dict_its12_otu = {}

# %%
for taxon in mean_reampl_free_its1_s.index:
    color_dict_its1_s[taxon] = get_color(color_dict_its1_s)
for taxon in mean_reampl_free_its1_otu.index:
    color_dict_its1_otu[taxon] = get_color(color_dict_its1_otu)
for taxon in mean_reampl_free_its2_s.index:
    color_dict_its2_s[taxon] = get_color(color_dict_its2_s)
for taxon in mean_reampl_free_its2_otu.index:
    color_dict_its2_otu[taxon] = get_color(color_dict_its2_otu)
for taxon in mean_reampl_free_its12_s.index:
    color_dict_its12_s[taxon] = get_color(color_dict_its12_s)
for taxon in mean_reampl_free_its12_otu.index:
    color_dict_its12_otu[taxon] = get_color(color_dict_its12_otu)

# %%
colors_its1_g = plt.cm.tab20.colors[:len(mean_reampl_free_its1_g)]
colors_its2_g = plt.cm.tab20.colors[:len(mean_reampl_free_its2_g)]
colors_its12_g = plt.cm.tab20.colors[:len(mean_reampl_free_its12_g)]

# %%
fig, ax = plt.subplots(3,3, figsize=(18,11))

for i, row in enumerate(mean_reampl_free_its1_g.iterrows()):
    ax[0,0].plot(range(3, 8,1), row[1], color=colors_its1_g[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_g.iterrows()):
    ax[0,0].plot(range(3, 8,1), row[1], color=colors_its1_g[i], linestyle = 'dashed')

ax[0,0].set_xlabel("k-mer")
ax[0,0].set_ylabel("Relative abundance")
ax[0,0].set_xticks(range(3,8,1))
#ax[0,0].set_yscale('log')
ax[0,0].set_title('Genus ITS1')
ax[0,0].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6, title = 'Taxonomy')
ax[0,0].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_s.iterrows()):
    ax[0,1].plot(range(3, 8,1), row[1], color=list(color_dict_its1_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_s.iterrows()):
    ax[0,1].plot(range(3, 8,1), row[1], color=list(color_dict_its1_s.values())[i], linestyle = 'dashed')

ax[0,1].set_xlabel("k-mer")
ax[0,1].set_ylabel("Relative abundance")
ax[0,1].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[0,1].set_title('Species ITS1')
ax[0,1].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6,title = 'Taxonomy', ncols=2)
ax[0,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_otu.iterrows()):
    ax[0,2].plot(range(3, 8,1), row[1], color=list(color_dict_its1_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_otu.iterrows()):
    ax[0,2].plot(range(3, 8,1), row[1], color=list(color_dict_its1_otu.values())[i], linestyle = 'dashed')

ax[0,2].set_xlabel("k-mer")
ax[0,2].set_ylabel("Relative abundance")
ax[0,2].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[0,2].set_title('OTU ITS1')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[0,2].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_g.iterrows()):
    ax[1,0].plot(range(3, 8,1), row[1], color=colors_its2_g[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_g.iterrows()):
    ax[1,0].plot(range(3, 8,1), row[1], color=colors_its2_g[i], linestyle = 'dashed')

ax[1,0].set_xlabel("k-mer")
ax[1,0].set_ylabel("Relative abundance")
ax[1,0].set_xticks(range(3,8,1))
#ax[1,0].set_yscale('log')
ax[1,0].set_title('Genus ITS2')
ax[1,0].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6,title = 'Taxonomy')
ax[1,0].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its2_s.iterrows()):
    ax[1,1].plot(range(3, 8,1), row[1], color=list(color_dict_its2_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_s.iterrows()):
    ax[1,1].plot(range(3, 8,1), row[1], color=list(color_dict_its2_s.values())[i], linestyle = 'dashed')

ax[1,1].set_xlabel("k-mer")
ax[1,1].set_ylabel("Relative abundance")
ax[1,1].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[1,1].set_title('Species ITS2')
ax[1,1].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6,title = 'Taxonomy')
ax[1,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its2_otu.iterrows()):
    ax[1,2].plot(range(3, 8,1), row[1], color=list(color_dict_its2_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_otu.iterrows()):
    ax[1,2].plot(range(3, 8,1), row[1], color=list(color_dict_its2_otu.values())[i], linestyle = 'dashed')

ax[1,2].set_xlabel("k-mer")
ax[1,2].set_ylabel("Relative abundance")
ax[1,2].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[1,2].set_title('OTU ITS2')
#ax[1,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[1,2].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its12_g.iterrows()):
    ax[2,0].plot(range(3, 8,1), row[1], color=colors_its12_g[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_g.iterrows()):
    ax[2,0].plot(range(3, 8,1), row[1], color=colors_its12_g[i], linestyle = 'dashed')

ax[2,0].set_xlabel("k-mer")
ax[2,0].set_ylabel("Relative abundance")
ax[2,0].set_xticks(range(3,8,1))
#ax[1,0].set_yscale('log')
ax[2,0].set_title('Genus ITS1_5.8S_ITS2')
ax[2,0].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6,title = 'Taxonomy')
ax[2,0].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its12_s.iterrows()):
    ax[2,1].plot(range(3, 8,1), row[1], color=list(color_dict_its12_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_s.iterrows()):
    ax[2,1].plot(range(3, 8,1), row[1], color=list(color_dict_its12_s.values())[i], linestyle = 'dashed')

ax[2,1].set_xlabel("k-mer")
ax[2,1].set_ylabel("Relative abundance")
ax[2,1].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[2,1].set_title('Species ITS1_5.8S_ITS2')
ax[2,1].legend(bbox_to_anchor=(1.05, 1.00), fontsize=6,title = 'Taxonomy', ncols=2)
ax[2,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its12_otu.iterrows()):
    ax[2,2].plot(range(3, 8,1), row[1], color=list(color_dict_its12_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_otu.iterrows()):
    ax[2,2].plot(range(3, 8,1), row[1], color=list(color_dict_its12_otu.values())[i], linestyle = 'dashed')

ax[2,2].set_xlabel("k-mer")
ax[2,2].set_ylabel("Relative abundance")
ax[2,2].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[2,2].set_title('OTU ITS1_5.8S_ITS2')
#ax[1,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[2,2].grid(alpha=0.7)
fig.tight_layout(pad=1, h_pad=0.7, w_pad=0.7)
fig.show()
fig.savefig("ITSs_all_plots_abundance_vs_kmers_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
fig.savefig("ITSs_all_plots_abundance_vs_kmers_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')
