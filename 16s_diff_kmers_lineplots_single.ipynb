# %% [markdown]
# **16S diff kmers plots**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import random

# %%
data_v34_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V3_V4_data_tax_df_OTU.csv', sep='\t',index_col=0)
data_v34_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V3_V4_data_tax_df_genus.csv', sep='\t',index_col=0)
data_v34_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V3_V4_data_tax_df_species.csv', sep='\t',index_col=0)
data_v19_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V1_V9_data_tax_df_OTU.csv', sep='\t',index_col=0)
data_v19_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V1_V9_data_tax_df_genus.csv', sep='\t',index_col=0)
data_v19_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/16s_diff_kmers_tables/kmers_3_7_V1_V9_data_tax_df_species.csv', sep='\t',index_col=0)

# %%
data_v34_otu
# Out:
#                                    V3_V4_1_3_kmer_size  V3_V4_1_4_kmer_size  \
# OTU_115_uncultured bacterium                  0.000000             0.000000
# OTU_78_uncultured Bifidobacterium             0.000000             0.000000
# OTU_234_uncultured bacterium                  0.000000             0.000000
# OTU_116_Lactococcus lactis                    0.000000             0.000000
# OTU_14_Mycoplasma gallisepticum               0.000000             0.000000
# ...                                                ...                  ...
# OTU_63_Streptococcus thermophilus             0.109642             0.114277
# OTU_123_Lactococcus lactis                    0.102765             0.105467
# OTU_254_Acinetobacter sp.                     0.109430             0.128409
# OTU_82_Bifidobacterium animalis               0.127323             0.128957
# OTU_29_Mycoplasma gallisepticum               0.137235             0.165430
#
# ...

# %%
v34_g_k3 = data_v34_g.iloc[:, [0,5,10]].mean(axis=1)
v34_g_k4 = data_v34_g.iloc[:, [1,6,11]].mean(axis=1)
v34_g_k5 = data_v34_g.iloc[:, [2,7,12]].mean(axis=1)
v34_g_k6 = data_v34_g.iloc[:, [3,8,13]].mean(axis=1)
v34_g_k7 = data_v34_g.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v34_g = pd.concat([v34_g_k3,v34_g_k4,v34_g_k5,v34_g_k6,v34_g_k7], axis=1)
v34_g_k3_r = data_v34_g.iloc[:, [15,20,25]].mean(axis=1)
v34_g_k4_r = data_v34_g.iloc[:, [16,21,26]].mean(axis=1)
v34_g_k5_r = data_v34_g.iloc[:, [17,22,27]].mean(axis=1)
v34_g_k6_r = data_v34_g.iloc[:, [18,23,28]].mean(axis=1)
v34_g_k7_r = data_v34_g.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v34_g = pd.concat([v34_g_k3_r,v34_g_k4_r,v34_g_k5_r,v34_g_k6_r,v34_g_k7_r], axis=1)

# %%
mean_reampl_free_v34_g
# Out:
#                              0         1         2         3         4
# Enterobacter          0.000000  0.000000  0.000000  0.000000  0.000000
# Aeromonas             0.000000  0.000000  0.000000  0.000000  0.000000
# Serratia              0.000000  0.000000  0.000000  0.000000  0.000000
# Rahnella1             0.000000  0.000000  0.000000  0.000000  0.000000
# Pseudocitrobacter     0.000000  0.000000  0.000000  0.000000  0.000000
# Kluyvera              0.000000  0.000000  0.000000  0.000000  0.000000
# Lactobacillus         0.000136  0.000110  0.000000  0.000328  0.000195
# uncultured            0.000000  0.000000  0.000000  0.000000  0.000000
# Staphylococcus        0.001360  0.001567  0.001709  0.001419  0.001564
# Yersinia              0.101519  0.101634  0.101588  0.102236  0.103240
# Escherichia-Shigella  0.112713  0.112506  0.112431  0.112125  0.113789
# Klebsiella            0.126700  0.126461  0.125923  0.126306  0.125053
# ...

# %%
v34_s_k3 = data_v34_s.iloc[:, [0,5,10]].mean(axis=1)
v34_s_k4 = data_v34_s.iloc[:, [1,6,11]].mean(axis=1)
v34_s_k5 = data_v34_s.iloc[:, [2,7,12]].mean(axis=1)
v34_s_k6 = data_v34_s.iloc[:, [3,8,13]].mean(axis=1)
v34_s_k7 = data_v34_s.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v34_s = pd.concat([v34_s_k3,v34_s_k4,v34_s_k5,v34_s_k6,v34_s_k7], axis=1)
v34_s_k3_r = data_v34_s.iloc[:, [15,20,25]].mean(axis=1)
v34_s_k4_r = data_v34_s.iloc[:, [16,21,26]].mean(axis=1)
v34_s_k5_r = data_v34_s.iloc[:, [17,22,27]].mean(axis=1)
v34_s_k6_r = data_v34_s.iloc[:, [18,23,28]].mean(axis=1)
v34_s_k7_r = data_v34_s.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v34_s = pd.concat([v34_s_k3_r,v34_s_k4_r,v34_s_k5_r,v34_s_k6_r,v34_s_k7_r], axis=1)

# %%
v34_otu_k3 = data_v34_otu.iloc[:, [0,5,10]].mean(axis=1)
v34_otu_k4 = data_v34_otu.iloc[:, [1,6,11]].mean(axis=1)
v34_otu_k5 = data_v34_otu.iloc[:, [2,7,12]].mean(axis=1)
v34_otu_k6 = data_v34_otu.iloc[:, [3,8,13]].mean(axis=1)
v34_otu_k7 = data_v34_otu.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v34_otu = pd.concat([v34_otu_k3,v34_otu_k4,v34_otu_k5,v34_otu_k6,v34_otu_k7], axis=1)
v34_otu_k3_r = data_v34_otu.iloc[:, [15,20,25]].mean(axis=1)
v34_otu_k4_r = data_v34_otu.iloc[:, [16,21,26]].mean(axis=1)
v34_otu_k5_r = data_v34_otu.iloc[:, [17,22,27]].mean(axis=1)
v34_otu_k6_r = data_v34_otu.iloc[:, [18,23,28]].mean(axis=1)
v34_otu_k7_r = data_v34_otu.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v34_otu = pd.concat([v34_otu_k3_r,v34_otu_k4_r,v34_otu_k5_r,v34_otu_k6_r,v34_otu_k7_r], axis=1)

# %%
v19_g_k3 = data_v19_g.iloc[:, [0,5,10]].mean(axis=1)
v19_g_k4 = data_v19_g.iloc[:, [1,6,11]].mean(axis=1)
v19_g_k5 = data_v19_g.iloc[:, [2,7,12]].mean(axis=1)
v19_g_k6 = data_v19_g.iloc[:, [3,8,13]].mean(axis=1)
v19_g_k7 = data_v19_g.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v19_g = pd.concat([v19_g_k3,v19_g_k4,v19_g_k5,v19_g_k6,v19_g_k7], axis=1)
v19_g_k3_r = data_v19_g.iloc[:, [15,20,25]].mean(axis=1)
v19_g_k4_r = data_v19_g.iloc[:, [16,21,26]].mean(axis=1)
v19_g_k5_r = data_v19_g.iloc[:, [17,22,27]].mean(axis=1)
v19_g_k6_r = data_v19_g.iloc[:, [18,23,28]].mean(axis=1)
v19_g_k7_r = data_v19_g.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v19_g = pd.concat([v19_g_k3_r,v19_g_k4_r,v19_g_k5_r,v19_g_k6_r,v19_g_k7_r], axis=1)

# %%
v19_s_k3 = data_v19_s.iloc[:, [0,5,10]].mean(axis=1)
v19_s_k4 = data_v19_s.iloc[:, [1,6,11]].mean(axis=1)
v19_s_k5 = data_v19_s.iloc[:, [2,7,12]].mean(axis=1)
v19_s_k6 = data_v19_s.iloc[:, [3,8,13]].mean(axis=1)
v19_s_k7 = data_v19_s.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v19_s = pd.concat([v19_s_k3,v19_s_k4,v19_s_k5,v19_s_k6,v19_s_k7], axis=1)
v19_s_k3_r = data_v19_s.iloc[:, [15,20,25]].mean(axis=1)
v19_s_k4_r = data_v19_s.iloc[:, [16,21,26]].mean(axis=1)
v19_s_k5_r = data_v19_s.iloc[:, [17,22,27]].mean(axis=1)
v19_s_k6_r = data_v19_s.iloc[:, [18,23,28]].mean(axis=1)
v19_s_k7_r = data_v19_s.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v19_s = pd.concat([v19_s_k3_r,v19_s_k4_r,v19_s_k5_r,v19_s_k6_r,v19_s_k7_r], axis=1)

# %%
v19_otu_k3 = data_v19_otu.iloc[:, [0,5,10]].mean(axis=1)
v19_otu_k4 = data_v19_otu.iloc[:, [1,6,11]].mean(axis=1)
v19_otu_k5 = data_v19_otu.iloc[:, [2,7,12]].mean(axis=1)
v19_otu_k6 = data_v19_otu.iloc[:, [3,8,13]].mean(axis=1)
v19_otu_k7 = data_v19_otu.iloc[:, [4,9,14]].mean(axis=1)
mean_reampl_free_v19_otu = pd.concat([v19_otu_k3,v19_otu_k4,v19_otu_k5,v19_otu_k6,v19_otu_k7], axis=1)
v19_otu_k3_r = data_v19_otu.iloc[:, [15,20,25]].mean(axis=1)
v19_otu_k4_r = data_v19_otu.iloc[:, [16,21,26]].mean(axis=1)
v19_otu_k5_r = data_v19_otu.iloc[:, [17,22,27]].mean(axis=1)
v19_otu_k6_r = data_v19_otu.iloc[:, [18,23,28]].mean(axis=1)
v19_otu_k7_r = data_v19_otu.iloc[:, [19,24,29]].mean(axis=1)
mean_reampl_v19_otu = pd.concat([v19_otu_k3_r,v19_otu_k4_r,v19_otu_k5_r,v19_otu_k6_r,v19_otu_k7_r], axis=1)

# %%
def get_color(obj_dict):
    color = ''
    while color not in obj_dict.values() and color == '':
        color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color
color_dict_v34_s = {}
color_dict_v34_otu = {}
color_dict_v19_s = {}
color_dict_v19_otu = {}

# %%
for taxon in mean_reampl_free_v34_s.index:
    color_dict_v34_s[taxon] = get_color(color_dict_v34_s)
#color_dict_v34_s
for taxon in mean_reampl_free_v34_otu.index:
    color_dict_v34_otu[taxon] = get_color(color_dict_v34_otu)
#color_dict_v34_otu
for taxon in mean_reampl_free_v19_otu.index:
    color_dict_v19_otu[taxon] = get_color(color_dict_v19_otu)
for taxon in mean_reampl_free_v19_s.index:
    color_dict_v19_s[taxon] = get_color(color_dict_v19_s)

# %%
colors_v34_g = plt.cm.tab20.colors[:len(mean_reampl_free_v34_g)]
colors_v19_g = plt.cm.tab20.colors[:len(mean_reampl_free_v34_g)]

# %%
fig, ax = plt.subplots(2,3, figsize=(14,7))

for i, row in enumerate(mean_reampl_free_v34_g.iterrows()):
    ax[0,0].plot(range(3, 8,1), row[1], color=colors_v34_g[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v34_g.iterrows()):
    ax[0,0].plot(range(3, 8,1), row[1], color=colors_v34_g[i], linestyle = 'dashed')

ax[0,0].set_xlabel("k-mer")
ax[0,0].set_ylabel("Relative abundance")
ax[0,0].set_xticks(range(3,8,1))
#ax[0,0].set_yscale('log')
ax[0,0].set_title('Genus V3-V4')
ax[0,0].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6, title = 'Taxonomy')
ax[0,0].grid(alpha=0.7)



for i, row in enumerate(mean_reampl_free_v34_s.iterrows()):
    ax[0,1].plot(range(3, 8,1), row[1], color=list(color_dict_v34_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v34_s.iterrows()):
    ax[0,1].plot(range(3, 8,1), row[1], color=list(color_dict_v34_s.values())[i], linestyle = 'dashed')

ax[0,1].set_xlabel("k-mer")
ax[0,1].set_ylabel("Relative abundance")
ax[0,1].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[0,1].set_title('Species V3-V4')
ax[0,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy')
ax[0,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_v34_otu.iterrows()):
    ax[0,2].plot(range(3, 8,1), row[1], color=list(color_dict_v34_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v34_otu.iterrows()):
    ax[0,2].plot(range(3, 8,1), row[1], color=list(color_dict_v34_otu.values())[i], linestyle = 'dashed')

ax[0,2].set_xlabel("k-mer")
ax[0,2].set_ylabel("Relative abundance")
ax[0,2].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[0,2].set_title('OTU V3-V4')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[0,2].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_v19_g.iterrows()):
    ax[1,0].plot(range(3, 8,1), row[1], color=colors_v19_g[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v19_g.iterrows()):
    ax[1,0].plot(range(3, 8,1), row[1], color=colors_v19_g[i], linestyle = 'dashed')

ax[1,0].set_xlabel("k-mer")
ax[1,0].set_ylabel("Relative abundance")
ax[1,0].set_xticks(range(3,8,1))
#ax[1,0].set_yscale('log')
ax[1,0].set_title('Genus V1-V9')
ax[1,0].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy')
ax[1,0].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_v19_s.iterrows()):
    ax[1,1].plot(range(3, 8,1), row[1], color=list(color_dict_v19_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v19_s.iterrows()):
    ax[1,1].plot(range(3, 8,1), row[1], color=list(color_dict_v19_s.values())[i], linestyle = 'dashed')

ax[1,1].set_xlabel("k-mer")
ax[1,1].set_ylabel("Relative abundance")
ax[1,1].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[1,1].set_title('Species V1-V9')
ax[1,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy')
ax[1,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_v19_otu.iterrows()):
    ax[1,2].plot(range(3, 8,1), row[1], color=list(color_dict_v19_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_v19_otu.iterrows()):
    ax[1,2].plot(range(3, 8,1), row[1], color=list(color_dict_v19_otu.values())[i], linestyle = 'dashed')

ax[1,2].set_xlabel("k-mer")
ax[1,2].set_ylabel("Relative abundance")
ax[1,2].set_xticks(range(3,8,1))
#ax.set_yscale('log')
ax[1,2].set_title('OTU V1-V9')
#ax[1,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[1,2].grid(alpha=0.7)

fig.show()
fig.tight_layout()
#fig.savefig("16S_all_plots_abundance_vs_kmers_SINGLE.pdf",format="pdf", bbox_inches="tight")
#fig.savefig("16S_all_plots_abundance_vs_kmers_SINGLE.png", dpi=800, format="png", bbox_inches='tight')
