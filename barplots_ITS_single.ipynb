# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import random
import numpy as np
import re
import plotly.express as px
import plotly.subplots as sp
import seaborn as sns

# %%
data_its1_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_1_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its1_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_1_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its1_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_1_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

data_its2_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_2_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its2_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_2_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its2_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_2_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

data_its12_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_12_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its12_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_12_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its12_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_new_db_single/single_ITS_12_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

# %%
fig = px.bar(data_its12_g_sorted.T, 
             y=data_its12_g_sorted.index, 
             x=data_its12_g_sorted.columns,
             width=1600, 
             height=1000, 
            # color=data_tax_df.index,
             labels={'value': 'Relative abundance', 'index':'Samples'}, 
             template='simple_white', title = 'ITS full genus')
            # color_discrete_map=Color_collection)
#fig.update_layout(yaxis_range=[0, 1], legend_title_text='Taxon', legend_title_side='top center')
fig.update_traces(marker_line_width=1.1, marker_line_color='#202020', opacity=0.8)
fig.update_yaxes(ticksuffix = "  ")
fig.show()

# %%
fig = px.bar(data_its12_s_sorted.T, 
             y=data_its12_s_sorted.index, 
             x=data_its12_s_sorted.columns,
             width=1600, 
             height=1000, 
            # color=data_tax_df.index,
             labels={'value': 'Relative abundance', 'index':'Samples'}, 
             template='simple_white', title = 'ITS full species',
             color_discrete_map=color_collection_its12_s)
#fig.update_layout(yaxis_range=[0, 1], legend_title_text='Taxon', legend_title_side='top center')
fig.update_traces(marker_line_width=1.1, marker_line_color='#202020', opacity=0.8)
fig.update_yaxes(ticksuffix = "  ")
fig.show()

# %%
data_its1_g

# %%
number_mapping = {col: int(col.split('_')[-2]) for col in data_its1_g.columns}
sorted_columns = sorted(number_mapping, key=number_mapping.get)
data_its1_g_sorted = data_its1_g[sorted_columns]
data_its1_s_sorted = data_its1_s[sorted_columns]
data_its1_otu_sorted = data_its1_otu[sorted_columns]

# %%
data_its1_g_sorted.columns
# Out:
# Index(['ITS1_1_200_reads', 'ITS1_2_200_reads', 'ITS1_3_200_reads',
#        'ITS1_R1_200_reads', 'ITS1_R2_200_reads', 'ITS1_R3_200_reads',
#        'ITS1_1_250_reads', 'ITS1_2_250_reads', 'ITS1_3_250_reads',
#        'ITS1_R1_250_reads', 'ITS1_R2_250_reads', 'ITS1_R3_250_reads',
#        'ITS1_1_300_reads', 'ITS1_2_300_reads', 'ITS1_3_300_reads',
#        'ITS1_R1_300_reads', 'ITS1_R2_300_reads', 'ITS1_R3_300_reads',
#        'ITS1_1_500_reads', 'ITS1_2_500_reads', 'ITS1_3_500_reads',
#        'ITS1_R1_500_reads', 'ITS1_R2_500_reads', 'ITS1_R3_500_reads',
#        'ITS1_1_1000_reads', 'ITS1_2_1000_reads', 'ITS1_3_1000_reads',
#        'ITS1_R1_1000_reads', 'ITS1_R2_1000_reads', 'ITS1_R3_1000_reads',
#        'ITS1_1_3000_reads', 'ITS1_2_3000_reads', 'ITS1_3_3000_reads',
#        'ITS1_R1_3000_reads', 'ITS1_R2_3000_reads', 'ITS1_R3_3000_reads',
#        'ITS1_1_5000_reads', 'ITS1_2_5000_reads', 'ITS1_3_5000_reads',
#        'ITS1_R1_5000_reads', 'ITS1_R2_5000_reads', 'ITS1_R3_5000_reads',
#        'ITS1_1_10000_reads', 'ITS1_2_10000_reads', 'ITS1_3_10000_reads',
#        'ITS1_R1_10000_reads', 'ITS1_R2_10000_reads', 'ITS1_R3_10000_reads',
#        'ITS1_1_30000_reads', 'ITS1_2_30000_reads', 'ITS1_3_30000_reads',
#        'ITS1_R1_30000_reads', 'ITS1_R2_30000_reads', 'ITS1_R3_30000_reads',
#        'ITS1_1_50000_reads', 'ITS1_2_50000_reads', 'ITS1_3_50000_reads',
#        'ITS1_R1_50000_reads', 'ITS1_R2_50000_reads', 'ITS1_R3_50000_reads',
#        'ITS1_1_100000_reads', 'ITS1_2_100000_reads', 'ITS1_3_100000_reads',
#        'ITS1_R1_100000_reads', 'ITS1_R2_100000_reads', 'ITS1_R3_100000_reads',
#        'ITS1_1_150000_reads', 'ITS1_2_150000_reads', 'ITS1_3_150000_reads',
#        'ITS1_R1_150000_reads', 'ITS1_R2_150000_reads', 'ITS1_R3_150000_reads'],
#       dtype='object')

# %%
number_mapping2 = {col: int(col.split('_')[-2]) for col in data_its2_g.columns}
sorted_columns2 = sorted(number_mapping2, key=number_mapping2.get)
data_its2_g_sorted = data_its2_g[sorted_columns2]
data_its2_s_sorted = data_its2_s[sorted_columns2]
data_its2_otu_sorted = data_its2_otu[sorted_columns2]

# %%
number_mapping3 = {col: int(col.split('_')[-2]) for col in data_its12_g.columns}
sorted_columns3 = sorted(number_mapping3, key=number_mapping3.get)
data_its12_g_sorted = data_its12_g[sorted_columns3]
data_its12_s_sorted = data_its12_s[sorted_columns3]
data_its12_otu_sorted = data_its12_otu[sorted_columns3]

# %%
for column in data_its1_otu_sorted.columns: 
    data_its1_otu_sorted[column] = data_its1_otu_sorted[column]/data_its1_otu_sorted[column].sum()
for column in data_its2_otu_sorted.columns: 
    data_its2_otu_sorted[column] = data_its2_otu_sorted[column]/data_its2_otu_sorted[column].sum()
for column in data_its12_otu_sorted.columns: 
    data_its12_otu_sorted[column] = data_its12_otu_sorted[column]/data_its12_otu_sorted[column].sum()

# %%
number_mapping

# %%
data_its1_g_sorted

# %%
def get_color(obj_dict):
    color = ''
    while color not in obj_dict.values() and color == '':  
        color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color
color_collection_its1_g = {}
color_collection_its1_s = {}
color_collection_its1_otu = {}
color_collection_its2_g = {}
color_collection_its2_s = {}
color_collection_its2_otu = {}
color_collection_its12_g = {}
color_collection_its12_s = {}
color_collection_its12_otu = {}

# %%
for i in data_its1_g_sorted.index:
    color_collection_its1_g[i] = get_color(color_collection_its1_g)
for i in data_its1_s_sorted.index:
    color_collection_its1_s[i] = get_color(color_collection_its1_s)
for i in data_its1_otu_sorted.index:
    color_collection_its1_otu[i] = get_color(color_collection_its1_otu)
for i in data_its2_g_sorted.index:
    color_collection_its2_g[i] = get_color(color_collection_its2_g)
for i in data_its2_s_sorted.index:
    color_collection_its2_s[i] = get_color(color_collection_its2_s)
for i in data_its2_otu_sorted.index:
    color_collection_its2_otu[i] = get_color(color_collection_its2_otu)
for i in data_its12_g_sorted.index:
    color_collection_its12_g[i] = get_color(color_collection_its12_g)
for i in data_its12_s_sorted.index:
    color_collection_its12_s[i] = get_color(color_collection_its12_s)
for i in data_its12_otu_sorted.index:
    color_collection_its12_otu[i] = get_color(color_collection_its12_otu)

# %%
data_its1_g.index

# %%
color_collection

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_g_sorted.columns:
    for genus in data_its1_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_g[genus])
        bottom += data_its1_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000','150000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its1_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 Genus single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS1_genus_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS1_genus_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')
#plt.tight_layout()

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_s_sorted.columns:
    for genus in data_its1_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_s[genus])
        bottom += data_its1_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000','150000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its1_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 Species single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS1_species_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS1_species_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
data_its2_g
# Out:
#                   ITS2_1_100000_reads  ITS2_1_10000_reads  ITS2_1_1000_reads  \
# g__unidentified              0.000000            0.000000           0.000000
# g__Nakaseomyces              0.000000            0.000000           0.000000
# g__Magnusiomyces             0.001086            0.000000           0.000000
# g__Pichia                    0.000000            0.000000           0.000000
# g__Kluyveromyces             0.049357            0.049801           0.053571
# g__Rhodotorula               0.057073            0.059408           0.065051
# g__Meyerozyma                0.096113            0.098719           0.088010
# g__Issatchenkia              0.079137            0.081051           0.086735
# g__Yarrowia                  0.181795            0.174249           0.244898
# g__Candida                   0.300086            0.306537           0.307398
# g__Clavispora                0.235353            0.230234           0.154337
#
#                   ITS2_1_200_reads  ITS2_1_250_reads  ITS2_1_30000_reads  \
# g__unidentified           0.000000          0.000000            0.000000
# g__Nakaseomyces           0.000000          0.000000            0.000000
# g__Magnusiomyces          0.000000          0.000000            0.001089
# g__Pichia                 0.000000          0.000000            0.000000
# g__Kluyveromyces          0.000000          0.000000            0.049770
# g__Rhodotorula            0.000000          0.000000            0.056689
# g__Meyerozyma             0.000000          0.113300            0.098030
# g__Issatchenkia           0.000000          0.000000            0.077623
# g__Yarrowia               0.563636          0.201970            0.182466
# g__Candida                0.436364          0.379310            0.298479
# g__Clavispora             0.000000          0.305419            0.235854
#
#                   ITS2_1_3000_reads  ITS2_1_300_reads  ITS2_1_50000_reads  \
# g__unidentified            0.000000          0.000000            0.000000
# g__Nakaseomyces            0.000000          0.000000            0.000000
# g__Magnusiomyces           0.000000          0.000000            0.001097
# g__Pichia                  0.000000          0.000000            0.000000
# g__Kluyveromyces           0.051134          0.000000            0.048564
# g__Rhodotorula             0.050774          0.000000            0.056157
# g__Meyerozyma              0.099028          0.102881            0.096004
# g__Issatchenkia            0.082823          0.000000            0.077922
# g__Yarrowia                0.197695          0.213992            0.175614
# g__Candida                 0.296003          0.395062            0.301201
# g__Clavispora              0.222542          0.288066            0.243441
#
#                   ITS2_1_5000_reads  ...  ITS2_R3_10000_reads  \
# g__unidentified            0.000000  ...             0.000000
# g__Nakaseomyces            0.000000  ...             0.000000
# g__Magnusiomyces           0.000000  ...             0.002556
# g__Pichia                  0.000000  ...             0.000000
# g__Kluyveromyces           0.050536  ...             0.063466
# g__Rhodotorula             0.054474  ...             0.072469
# g__Meyerozyma              0.107854  ...             0.070357
# g__Issatchenkia            0.078320  ...             0.089363
# g__Yarrowia                0.211551  ...             0.214516
# g__Candida                 0.277182  ...             0.252195
# g__Clavispora              0.220083  ...             0.235078
#
#                   ITS2_R3_1000_reads  ITS2_R3_200_reads  ITS2_R3_250_reads  \
# g__unidentified             0.000000           0.000000           0.000000
# g__Nakaseomyces             0.000000           0.000000           0.000000
# g__Magnusiomyces            0.000000           0.000000           0.000000
# g__Pichia                   0.000000           0.000000           0.000000
# g__Kluyveromyces            0.072905           0.000000           0.000000
# g__Rhodotorula              0.081610           0.000000           0.000000
# g__Meyerozyma               0.064200           0.000000           0.000000
# g__Issatchenkia             0.091404           0.000000           0.197279
# g__Yarrowia                 0.245919           0.417582           0.333333
# g__Candida                  0.206746           0.000000           0.000000
# g__Clavispora               0.237214           0.582418           0.469388
#
#                   ITS2_R3_30000_reads  ITS2_R3_3000_reads  ITS2_R3_300_reads  \
# g__unidentified              0.000000            0.000000           0.000000
# g__Nakaseomyces              0.000000            0.000000           0.000000
# g__Magnusiomyces             0.002476            0.000000           0.000000
# g__Pichia                    0.000000            0.000000           0.000000
# g__Kluyveromyces             0.061821            0.067752           0.090909
# g__Rhodotorula               0.072261            0.075322           0.087121
# g__Meyerozyma                0.069750            0.062074           0.000000
# g__Issatchenkia              0.089950            0.087812           0.125000
# g__Yarrowia                  0.218040            0.250946           0.238636
# g__Candida                   0.246887            0.244512           0.162879
# g__Clavispora                0.238815            0.211582           0.295455
#
#                   ITS2_R3_50000_reads  ITS2_R3_5000_reads  ITS2_R3_500_reads
# g__unidentified              0.000000            0.000000           0.000000
# g__Nakaseomyces              0.000883            0.000000           0.000000
# g__Magnusiomyces             0.002455            0.000000           0.000000
# g__Pichia                    0.000000            0.000000           0.000000
# g__Kluyveromyces             0.058113            0.066323           0.081301
# g__Rhodotorula               0.071032            0.077806           0.071138
# g__Meyerozyma                0.068749            0.074994           0.060976
# g__Issatchenkia              0.090733            0.103586           0.093496
# g__Yarrowia                  0.219598            0.213265           0.195122
# g__Candida                   0.240397            0.260605           0.233740
# g__Clavispora                0.248041            0.203422           0.264228
#
# [11 rows x 66 columns]

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_g_sorted.columns:
    for genus in data_its2_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_g[genus])
        bottom += data_its2_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its2_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 Genus single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS2_genus_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS2_genus_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_s_sorted.columns:
    for genus in data_its2_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_s[genus])
        bottom += data_its2_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its2_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 Species single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS2_species_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS2_species_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_g_sorted.columns:
    for genus in data_its12_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_g[genus])
        bottom += data_its12_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 Genus single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_genus_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_genus_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_s_sorted.columns:
    for genus in data_its12_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_s[genus])
        bottom += data_its12_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 Species single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_species_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_species_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_otu_sorted.columns:
    for genus in data_its12_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_otu[genus])
        bottom += data_its12_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 OTU single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_OTU_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_OTU_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_otu_sorted.columns:
    for genus in data_its1_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_otu[genus])
        bottom += data_its1_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000','150000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 OTU single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_1_OTU_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_1_OTU_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_otu_sorted.columns:
    for genus in data_its2_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_otu[genus])
        bottom += data_its2_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['200','250','300','500','1000','3000','5000','10000','30000','50000','100000']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its22_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 OTU single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_2_OTU_abundance_SINGLE_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_2_OTU_abundance_SINGLE_new_db.png", dpi=800, format="png", bbox_inches='tight')
