# %% [markdown]
# **ITSs mean taxonomy vs reads number**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import random
import numpy as np

# %%
data_its1_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_1_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its1_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_1_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its1_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_1_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

data_its2_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_2_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its2_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_2_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its2_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_2_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

data_its12_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_12_merged_otu_table_all_samples_all_reads_new_db.csv',index_col=0)
data_its12_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_12_data_tax_df_genus_new_db.csv', sep='\t',index_col=0)
data_its12_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_ITS_12_data_tax_df_species_new_db.csv', sep='\t',index_col=0)

# %%
for column in data_its1_otu.columns: 
    data_its1_otu[column] = data_its1_otu[column]/data_its1_otu[column].sum()
for column in data_its2_otu.columns: 
    data_its2_otu[column] = data_its2_otu[column]/data_its2_otu[column].sum()
for column in data_its12_otu.columns: 
    data_its12_otu[column] = data_its12_otu[column]/data_its12_otu[column].sum()

# %%
data_its2_g
# Out:
#                   ITS2_1_100000_reads  ITS2_1_10000_reads  ITS2_1_1000_reads  \
# g__Peltula                   0.000000            0.000000           0.000000
# g__Nakaseomyces              0.001209            0.000751           0.000000
# g__Magnusiomyces             0.001044            0.001394           0.000000
# g__Kluyveromyces             0.048149            0.053089           0.048066
# g__Rhodotorula               0.054772            0.056735           0.059789
# g__Meyerozyma                0.096106            0.093844           0.094959
# g__Pichia                    0.075082            0.073574           0.063306
# g__Clavispora                0.125319            0.120013           0.130129
# g__Yarrowia                  0.191057            0.185650           0.178195
# g__Candida                   0.407261            0.414951           0.425557
#
#                   ITS2_1_200_reads  ITS2_1_250_reads  ITS2_1_30000_reads  \
# ...

# %%
its1_otu_200_reads = data_its1_otu.iloc[:,[3,14,25]].mean(axis=1)
its1_otu_250_reads = data_its1_otu.iloc[:,[4,15,26]].mean(axis=1)
its1_otu_300_reads = data_its1_otu.iloc[:,[7,18,29]].mean(axis=1)
its1_otu_500_reads = data_its1_otu.iloc[:,[10,21,32]].mean(axis=1)
its1_otu_1000_reads = data_its1_otu.iloc[:,[2,13,24]].mean(axis=1)
its1_otu_3000_reads = data_its1_otu.iloc[:,[6,17,28]].mean(axis=1)
its1_otu_5000_reads = data_its1_otu.iloc[:,[9,20,31]].mean(axis=1)
its1_otu_10000_reads = data_its1_otu.iloc[:,[1,12,23]].mean(axis=1)
its1_otu_30000_reads = data_its1_otu.iloc[:,[5,16,27]].mean(axis=1)
its1_otu_50000_reads = data_its1_otu.iloc[:,[8,19,30]].mean(axis=1)
its1_otu_100000_reads = data_its1_otu.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its1_otu = pd.concat([its1_otu_200_reads,its1_otu_250_reads,its1_otu_300_reads,
                                      its1_otu_500_reads,its1_otu_1000_reads,its1_otu_3000_reads,its1_otu_5000_reads,
                                      its1_otu_10000_reads,its1_otu_30000_reads,its1_otu_50000_reads,its1_otu_100000_reads], axis = 1)

its1_otu_200_reads_r = data_its1_otu.iloc[:,[36,47,58]].mean(axis=1)
its1_otu_250_reads_r = data_its1_otu.iloc[:,[37,48,59]].mean(axis=1)
its1_otu_300_reads_r = data_its1_otu.iloc[:,[40,51,62]].mean(axis=1)
its1_otu_500_reads_r = data_its1_otu.iloc[:,[43,54,65]].mean(axis=1)
its1_otu_1000_reads_r = data_its1_otu.iloc[:,[35,46,57]].mean(axis=1)
its1_otu_3000_reads_r = data_its1_otu.iloc[:,[39,50,61]].mean(axis=1)
its1_otu_5000_reads_r = data_its1_otu.iloc[:,[42,53,64]].mean(axis=1)
its1_otu_10000_reads_r = data_its1_otu.iloc[:,[34,45,56]].mean(axis=1)
its1_otu_30000_reads_r = data_its1_otu.iloc[:,[38,49,60]].mean(axis=1)
its1_otu_50000_reads_r = data_its1_otu.iloc[:,[41,52,63]].mean(axis=1)
its1_otu_100000_reads_r = data_its1_otu.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its1_otu = pd.concat([its1_otu_200_reads_r,its1_otu_250_reads_r,its1_otu_300_reads_r,
                                      its1_otu_500_reads_r,its1_otu_1000_reads_r,its1_otu_3000_reads_r,its1_otu_5000_reads_r,
                                      its1_otu_10000_reads_r,its1_otu_30000_reads_r,its1_otu_50000_reads_r,its1_otu_100000_reads_r], axis = 1)
its1_g_200_reads = data_its1_g.iloc[:,[3,14,25]].mean(axis=1)
its1_g_250_reads = data_its1_g.iloc[:,[4,15,26]].mean(axis=1)
its1_g_300_reads = data_its1_g.iloc[:,[7,18,29]].mean(axis=1)
its1_g_500_reads = data_its1_g.iloc[:,[10,21,32]].mean(axis=1)
its1_g_1000_reads = data_its1_g.iloc[:,[2,13,24]].mean(axis=1)
its1_g_3000_reads = data_its1_g.iloc[:,[6,17,28]].mean(axis=1)
its1_g_5000_reads = data_its1_g.iloc[:,[9,20,31]].mean(axis=1)
its1_g_10000_reads = data_its1_g.iloc[:,[1,12,23]].mean(axis=1)
its1_g_30000_reads = data_its1_g.iloc[:,[5,16,27]].mean(axis=1)
its1_g_50000_reads = data_its1_g.iloc[:,[8,19,30]].mean(axis=1)
its1_g_100000_reads = data_its1_g.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its1_g = pd.concat([its1_g_200_reads,its1_g_250_reads,its1_g_300_reads,
                                      its1_g_500_reads,its1_g_1000_reads,its1_g_3000_reads,its1_g_5000_reads,
                                      its1_g_10000_reads,its1_g_30000_reads,its1_g_50000_reads,its1_g_100000_reads], axis = 1)

its1_g_200_reads_r = data_its1_g.iloc[:,[36,47,58]].mean(axis=1)
its1_g_250_reads_r = data_its1_g.iloc[:,[37,48,59]].mean(axis=1)
its1_g_300_reads_r = data_its1_g.iloc[:,[40,51,62]].mean(axis=1)
its1_g_500_reads_r = data_its1_g.iloc[:,[43,54,65]].mean(axis=1)
its1_g_1000_reads_r = data_its1_g.iloc[:,[35,46,57]].mean(axis=1)
its1_g_3000_reads_r = data_its1_g.iloc[:,[39,50,61]].mean(axis=1)
its1_g_5000_reads_r = data_its1_g.iloc[:,[42,53,64]].mean(axis=1)
its1_g_10000_reads_r = data_its1_g.iloc[:,[34,45,56]].mean(axis=1)
its1_g_30000_reads_r = data_its1_g.iloc[:,[38,49,60]].mean(axis=1)
its1_g_50000_reads_r = data_its1_g.iloc[:,[41,52,63]].mean(axis=1)
its1_g_100000_reads_r = data_its1_g.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its1_g = pd.concat([its1_g_200_reads_r,its1_g_250_reads_r,its1_g_300_reads_r,
                                      its1_g_500_reads_r,its1_g_1000_reads_r,its1_g_3000_reads_r,its1_g_5000_reads_r,
                                      its1_g_10000_reads_r,its1_g_30000_reads_r,its1_g_50000_reads_r,its1_g_100000_reads_r], axis = 1)
its1_s_200_reads = data_its1_s.iloc[:,[3,14,25]].mean(axis=1)
its1_s_250_reads = data_its1_s.iloc[:,[4,15,26]].mean(axis=1)
its1_s_300_reads = data_its1_s.iloc[:,[7,18,29]].mean(axis=1)
its1_s_500_reads = data_its1_s.iloc[:,[10,21,32]].mean(axis=1)
its1_s_1000_reads = data_its1_s.iloc[:,[2,13,24]].mean(axis=1)
its1_s_3000_reads = data_its1_s.iloc[:,[6,17,28]].mean(axis=1)
its1_s_5000_reads = data_its1_s.iloc[:,[9,20,31]].mean(axis=1)
its1_s_10000_reads = data_its1_s.iloc[:,[1,12,23]].mean(axis=1)
its1_s_30000_reads = data_its1_s.iloc[:,[5,16,27]].mean(axis=1)
its1_s_50000_reads = data_its1_s.iloc[:,[8,19,30]].mean(axis=1)
its1_s_100000_reads = data_its1_s.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its1_s = pd.concat([its1_s_200_reads,its1_s_250_reads,its1_s_300_reads,
                                      its1_s_500_reads,its1_s_1000_reads,its1_s_3000_reads,its1_s_5000_reads,
                                      its1_s_10000_reads,its1_s_30000_reads,its1_s_50000_reads,its1_s_100000_reads], axis = 1)

its1_s_200_reads_r = data_its1_s.iloc[:,[36,47,58]].mean(axis=1)
its1_s_250_reads_r = data_its1_s.iloc[:,[37,48,59]].mean(axis=1)
its1_s_300_reads_r = data_its1_s.iloc[:,[40,51,62]].mean(axis=1)
its1_s_500_reads_r = data_its1_s.iloc[:,[43,54,65]].mean(axis=1)
its1_s_1000_reads_r = data_its1_s.iloc[:,[35,46,57]].mean(axis=1)
its1_s_3000_reads_r = data_its1_s.iloc[:,[39,50,61]].mean(axis=1)
its1_s_5000_reads_r = data_its1_s.iloc[:,[42,53,64]].mean(axis=1)
its1_s_10000_reads_r = data_its1_s.iloc[:,[34,45,56]].mean(axis=1)
its1_s_30000_reads_r = data_its1_s.iloc[:,[38,49,60]].mean(axis=1)
its1_s_50000_reads_r = data_its1_s.iloc[:,[41,52,63]].mean(axis=1)
its1_s_100000_reads_r = data_its1_s.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its1_s = pd.concat([its1_s_200_reads_r,its1_s_250_reads_r,its1_s_300_reads_r,
                                      its1_s_500_reads_r,its1_s_1000_reads_r,its1_s_3000_reads_r,its1_s_5000_reads_r,
                                      its1_s_10000_reads_r,its1_s_30000_reads_r,its1_s_50000_reads_r,its1_s_100000_reads_r], axis = 1)

# %%
its2_otu_200_reads = data_its2_otu.iloc[:,[3,14,25]].mean(axis=1)
its2_otu_250_reads = data_its2_otu.iloc[:,[4,15,26]].mean(axis=1)
its2_otu_300_reads = data_its2_otu.iloc[:,[7,18,29]].mean(axis=1)
its2_otu_500_reads = data_its2_otu.iloc[:,[10,21,32]].mean(axis=1)
its2_otu_1000_reads = data_its2_otu.iloc[:,[2,13,24]].mean(axis=1)
its2_otu_3000_reads = data_its2_otu.iloc[:,[6,17,28]].mean(axis=1)
its2_otu_5000_reads = data_its2_otu.iloc[:,[9,20,31]].mean(axis=1)
its2_otu_10000_reads = data_its2_otu.iloc[:,[1,12,23]].mean(axis=1)
its2_otu_30000_reads = data_its2_otu.iloc[:,[5,16,27]].mean(axis=1)
its2_otu_50000_reads = data_its2_otu.iloc[:,[8,19,30]].mean(axis=1)
its2_otu_100000_reads = data_its2_otu.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its2_otu = pd.concat([its2_otu_200_reads,its2_otu_250_reads,its2_otu_300_reads,
                                      its2_otu_500_reads,its2_otu_1000_reads,its2_otu_3000_reads,its2_otu_5000_reads,
                                      its2_otu_10000_reads,its2_otu_30000_reads,its2_otu_50000_reads,its2_otu_100000_reads], axis = 1)

its2_otu_200_reads_r = data_its2_otu.iloc[:,[36,47,58]].mean(axis=1)
its2_otu_250_reads_r = data_its2_otu.iloc[:,[37,48,59]].mean(axis=1)
its2_otu_300_reads_r = data_its2_otu.iloc[:,[40,51,62]].mean(axis=1)
its2_otu_500_reads_r = data_its2_otu.iloc[:,[43,54,65]].mean(axis=1)
its2_otu_1000_reads_r = data_its2_otu.iloc[:,[35,46,57]].mean(axis=1)
its2_otu_3000_reads_r = data_its2_otu.iloc[:,[39,50,61]].mean(axis=1)
its2_otu_5000_reads_r = data_its2_otu.iloc[:,[42,53,64]].mean(axis=1)
its2_otu_10000_reads_r = data_its2_otu.iloc[:,[34,45,56]].mean(axis=1)
its2_otu_30000_reads_r = data_its2_otu.iloc[:,[38,49,60]].mean(axis=1)
its2_otu_50000_reads_r = data_its2_otu.iloc[:,[41,52,63]].mean(axis=1)
its2_otu_100000_reads_r = data_its2_otu.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its2_otu = pd.concat([its2_otu_200_reads_r,its2_otu_250_reads_r,its2_otu_300_reads_r,
                                      its2_otu_500_reads_r,its2_otu_1000_reads_r,its2_otu_3000_reads_r,its2_otu_5000_reads_r,
                                      its2_otu_10000_reads_r,its2_otu_30000_reads_r,its2_otu_50000_reads_r,its2_otu_100000_reads_r], axis = 1)
its2_g_200_reads = data_its2_g.iloc[:,[3,14,25]].mean(axis=1)
its2_g_250_reads = data_its2_g.iloc[:,[4,15,26]].mean(axis=1)
its2_g_300_reads = data_its2_g.iloc[:,[7,18,29]].mean(axis=1)
its2_g_500_reads = data_its2_g.iloc[:,[10,21,32]].mean(axis=1)
its2_g_1000_reads = data_its2_g.iloc[:,[2,13,24]].mean(axis=1)
its2_g_3000_reads = data_its2_g.iloc[:,[6,17,28]].mean(axis=1)
its2_g_5000_reads = data_its2_g.iloc[:,[9,20,31]].mean(axis=1)
its2_g_10000_reads = data_its2_g.iloc[:,[1,12,23]].mean(axis=1)
its2_g_30000_reads = data_its2_g.iloc[:,[5,16,27]].mean(axis=1)
its2_g_50000_reads = data_its2_g.iloc[:,[8,19,30]].mean(axis=1)
its2_g_100000_reads = data_its2_g.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its2_g = pd.concat([its2_g_200_reads,its2_g_250_reads,its2_g_300_reads,
                                      its2_g_500_reads,its2_g_1000_reads,its2_g_3000_reads,its2_g_5000_reads,
                                      its2_g_10000_reads,its2_g_30000_reads,its2_g_50000_reads,its2_g_100000_reads], axis = 1)

its2_g_200_reads_r = data_its2_g.iloc[:,[36,47,58]].mean(axis=1)
its2_g_250_reads_r = data_its2_g.iloc[:,[37,48,59]].mean(axis=1)
its2_g_300_reads_r = data_its2_g.iloc[:,[40,51,62]].mean(axis=1)
its2_g_500_reads_r = data_its2_g.iloc[:,[43,54,65]].mean(axis=1)
its2_g_1000_reads_r = data_its2_g.iloc[:,[35,46,57]].mean(axis=1)
its2_g_3000_reads_r = data_its2_g.iloc[:,[39,50,61]].mean(axis=1)
its2_g_5000_reads_r = data_its2_g.iloc[:,[42,53,64]].mean(axis=1)
its2_g_10000_reads_r = data_its2_g.iloc[:,[34,45,56]].mean(axis=1)
its2_g_30000_reads_r = data_its2_g.iloc[:,[38,49,60]].mean(axis=1)
its2_g_50000_reads_r = data_its2_g.iloc[:,[41,52,63]].mean(axis=1)
its2_g_100000_reads_r = data_its2_g.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its2_g = pd.concat([its2_g_200_reads_r,its2_g_250_reads_r,its2_g_300_reads_r,
                                      its2_g_500_reads_r,its2_g_1000_reads_r,its2_g_3000_reads_r,its2_g_5000_reads_r,
                                      its2_g_10000_reads_r,its2_g_30000_reads_r,its2_g_50000_reads_r,its2_g_100000_reads_r], axis = 1)
its2_s_200_reads = data_its2_s.iloc[:,[3,14,25]].mean(axis=1)
its2_s_250_reads = data_its2_s.iloc[:,[4,15,26]].mean(axis=1)
its2_s_300_reads = data_its2_s.iloc[:,[7,18,29]].mean(axis=1)
its2_s_500_reads = data_its2_s.iloc[:,[10,21,32]].mean(axis=1)
its2_s_1000_reads = data_its2_s.iloc[:,[2,13,24]].mean(axis=1)
its2_s_3000_reads = data_its2_s.iloc[:,[6,17,28]].mean(axis=1)
its2_s_5000_reads = data_its2_s.iloc[:,[9,20,31]].mean(axis=1)
its2_s_10000_reads = data_its2_s.iloc[:,[1,12,23]].mean(axis=1)
its2_s_30000_reads = data_its2_s.iloc[:,[5,16,27]].mean(axis=1)
its2_s_50000_reads = data_its2_s.iloc[:,[8,19,30]].mean(axis=1)
its2_s_100000_reads = data_its2_s.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its2_s = pd.concat([its2_s_200_reads,its2_s_250_reads,its2_s_300_reads,
                                      its2_s_500_reads,its2_s_1000_reads,its2_s_3000_reads,its2_s_5000_reads,
                                      its2_s_10000_reads,its2_s_30000_reads,its2_s_50000_reads,its2_s_100000_reads], axis = 1)

its2_s_200_reads_r = data_its2_s.iloc[:,[36,47,58]].mean(axis=1)
its2_s_250_reads_r = data_its2_s.iloc[:,[37,48,59]].mean(axis=1)
its2_s_300_reads_r = data_its2_s.iloc[:,[40,51,62]].mean(axis=1)
its2_s_500_reads_r = data_its2_s.iloc[:,[43,54,65]].mean(axis=1)
its2_s_1000_reads_r = data_its2_s.iloc[:,[35,46,57]].mean(axis=1)
its2_s_3000_reads_r = data_its2_s.iloc[:,[39,50,61]].mean(axis=1)
its2_s_5000_reads_r = data_its2_s.iloc[:,[42,53,64]].mean(axis=1)
its2_s_10000_reads_r = data_its2_s.iloc[:,[34,45,56]].mean(axis=1)
its2_s_30000_reads_r = data_its2_s.iloc[:,[38,49,60]].mean(axis=1)
its2_s_50000_reads_r = data_its2_s.iloc[:,[41,52,63]].mean(axis=1)
its2_s_100000_reads_r = data_its2_s.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its2_s = pd.concat([its2_s_200_reads_r,its2_s_250_reads_r,its2_s_300_reads_r,
                                      its2_s_500_reads_r,its2_s_1000_reads_r,its2_s_3000_reads_r,its2_s_5000_reads_r,
                                      its2_s_10000_reads_r,its2_s_30000_reads_r,its2_s_50000_reads_r,its2_s_100000_reads_r], axis = 1)

# %%
its12_otu_200_reads = data_its12_otu.iloc[:,[3,14,25]].mean(axis=1)
its12_otu_250_reads = data_its12_otu.iloc[:,[4,15,26]].mean(axis=1)
its12_otu_300_reads = data_its12_otu.iloc[:,[7,18,29]].mean(axis=1)
its12_otu_500_reads = data_its12_otu.iloc[:,[10,21,32]].mean(axis=1)
its12_otu_1000_reads = data_its12_otu.iloc[:,[2,13,24]].mean(axis=1)
its12_otu_3000_reads = data_its12_otu.iloc[:,[6,17,28]].mean(axis=1)
its12_otu_5000_reads = data_its12_otu.iloc[:,[9,20,31]].mean(axis=1)
its12_otu_10000_reads = data_its12_otu.iloc[:,[1,12,23]].mean(axis=1)
its12_otu_30000_reads = data_its12_otu.iloc[:,[5,16,27]].mean(axis=1)
its12_otu_50000_reads = data_its12_otu.iloc[:,[8,19,30]].mean(axis=1)
its12_otu_100000_reads = data_its12_otu.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its12_otu = pd.concat([its12_otu_200_reads,its12_otu_250_reads,its12_otu_300_reads,
                                      its12_otu_500_reads,its12_otu_1000_reads,its12_otu_3000_reads,its12_otu_5000_reads,
                                      its12_otu_10000_reads,its12_otu_30000_reads,its12_otu_50000_reads,its12_otu_100000_reads], axis = 1)

its12_otu_200_reads_r = data_its12_otu.iloc[:,[36,47,58]].mean(axis=1)
its12_otu_250_reads_r = data_its12_otu.iloc[:,[37,48,59]].mean(axis=1)
its12_otu_300_reads_r = data_its12_otu.iloc[:,[40,51,62]].mean(axis=1)
its12_otu_500_reads_r = data_its12_otu.iloc[:,[43,54,65]].mean(axis=1)
its12_otu_1000_reads_r = data_its12_otu.iloc[:,[35,46,57]].mean(axis=1)
its12_otu_3000_reads_r = data_its12_otu.iloc[:,[39,50,61]].mean(axis=1)
its12_otu_5000_reads_r = data_its12_otu.iloc[:,[42,53,64]].mean(axis=1)
its12_otu_10000_reads_r = data_its12_otu.iloc[:,[34,45,56]].mean(axis=1)
its12_otu_30000_reads_r = data_its12_otu.iloc[:,[38,49,60]].mean(axis=1)
its12_otu_50000_reads_r = data_its12_otu.iloc[:,[41,52,63]].mean(axis=1)
its12_otu_100000_reads_r = data_its12_otu.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its12_otu = pd.concat([its12_otu_200_reads_r,its12_otu_250_reads_r,its12_otu_300_reads_r,
                                      its12_otu_500_reads_r,its12_otu_1000_reads_r,its12_otu_3000_reads_r,its12_otu_5000_reads_r,
                                      its12_otu_10000_reads_r,its12_otu_30000_reads_r,its12_otu_50000_reads_r,its12_otu_100000_reads_r], axis = 1)
its12_g_200_reads = data_its12_g.iloc[:,[3,14,25]].mean(axis=1)
its12_g_250_reads = data_its12_g.iloc[:,[4,15,26]].mean(axis=1)
its12_g_300_reads = data_its12_g.iloc[:,[7,18,29]].mean(axis=1)
its12_g_500_reads = data_its12_g.iloc[:,[10,21,32]].mean(axis=1)
its12_g_1000_reads = data_its12_g.iloc[:,[2,13,24]].mean(axis=1)
its12_g_3000_reads = data_its12_g.iloc[:,[6,17,28]].mean(axis=1)
its12_g_5000_reads = data_its12_g.iloc[:,[9,20,31]].mean(axis=1)
its12_g_10000_reads = data_its12_g.iloc[:,[1,12,23]].mean(axis=1)
its12_g_30000_reads = data_its12_g.iloc[:,[5,16,27]].mean(axis=1)
its12_g_50000_reads = data_its12_g.iloc[:,[8,19,30]].mean(axis=1)
its12_g_100000_reads = data_its12_g.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its12_g = pd.concat([its12_g_200_reads,its12_g_250_reads,its12_g_300_reads,
                                      its12_g_500_reads,its12_g_1000_reads,its12_g_3000_reads,its12_g_5000_reads,
                                      its12_g_10000_reads,its12_g_30000_reads,its12_g_50000_reads,its12_g_100000_reads], axis = 1)

its12_g_200_reads_r = data_its12_g.iloc[:,[36,47,58]].mean(axis=1)
its12_g_250_reads_r = data_its12_g.iloc[:,[37,48,59]].mean(axis=1)
its12_g_300_reads_r = data_its12_g.iloc[:,[40,51,62]].mean(axis=1)
its12_g_500_reads_r = data_its12_g.iloc[:,[43,54,65]].mean(axis=1)
its12_g_1000_reads_r = data_its12_g.iloc[:,[35,46,57]].mean(axis=1)
its12_g_3000_reads_r = data_its12_g.iloc[:,[39,50,61]].mean(axis=1)
its12_g_5000_reads_r = data_its12_g.iloc[:,[42,53,64]].mean(axis=1)
its12_g_10000_reads_r = data_its12_g.iloc[:,[34,45,56]].mean(axis=1)
its12_g_30000_reads_r = data_its12_g.iloc[:,[38,49,60]].mean(axis=1)
its12_g_50000_reads_r = data_its12_g.iloc[:,[41,52,63]].mean(axis=1)
its12_g_100000_reads_r = data_its12_g.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its12_g = pd.concat([its12_g_200_reads_r,its12_g_250_reads_r,its12_g_300_reads_r,
                                      its12_g_500_reads_r,its12_g_1000_reads_r,its12_g_3000_reads_r,its12_g_5000_reads_r,
                                      its12_g_10000_reads_r,its12_g_30000_reads_r,its12_g_50000_reads_r,its12_g_100000_reads_r], axis = 1)
its12_s_200_reads = data_its12_s.iloc[:,[3,14,25]].mean(axis=1)
its12_s_250_reads = data_its12_s.iloc[:,[4,15,26]].mean(axis=1)
its12_s_300_reads = data_its12_s.iloc[:,[7,18,29]].mean(axis=1)
its12_s_500_reads = data_its12_s.iloc[:,[10,21,32]].mean(axis=1)
its12_s_1000_reads = data_its12_s.iloc[:,[2,13,24]].mean(axis=1)
its12_s_3000_reads = data_its12_s.iloc[:,[6,17,28]].mean(axis=1)
its12_s_5000_reads = data_its12_s.iloc[:,[9,20,31]].mean(axis=1)
its12_s_10000_reads = data_its12_s.iloc[:,[1,12,23]].mean(axis=1)
its12_s_30000_reads = data_its12_s.iloc[:,[5,16,27]].mean(axis=1)
its12_s_50000_reads = data_its12_s.iloc[:,[8,19,30]].mean(axis=1)
its12_s_100000_reads = data_its12_s.iloc[:,[0,11,22]].mean(axis=1)
mean_reampl_free_its12_s = pd.concat([its12_s_200_reads,its12_s_250_reads,its12_s_300_reads,
                                      its12_s_500_reads,its12_s_1000_reads,its12_s_3000_reads,its12_s_5000_reads,
                                      its12_s_10000_reads,its12_s_30000_reads,its12_s_50000_reads,its12_s_100000_reads], axis = 1)

its12_s_200_reads_r = data_its12_s.iloc[:,[36,47,58]].mean(axis=1)
its12_s_250_reads_r = data_its12_s.iloc[:,[37,48,59]].mean(axis=1)
its12_s_300_reads_r = data_its12_s.iloc[:,[40,51,62]].mean(axis=1)
its12_s_500_reads_r = data_its12_s.iloc[:,[43,54,65]].mean(axis=1)
its12_s_1000_reads_r = data_its12_s.iloc[:,[35,46,57]].mean(axis=1)
its12_s_3000_reads_r = data_its12_s.iloc[:,[39,50,61]].mean(axis=1)
its12_s_5000_reads_r = data_its12_s.iloc[:,[42,53,64]].mean(axis=1)
its12_s_10000_reads_r = data_its12_s.iloc[:,[34,45,56]].mean(axis=1)
its12_s_30000_reads_r = data_its12_s.iloc[:,[38,49,60]].mean(axis=1)
its12_s_50000_reads_r = data_its12_s.iloc[:,[41,52,63]].mean(axis=1)
its12_s_100000_reads_r = data_its12_s.iloc[:,[33,44,55]].mean(axis=1)
mean_reampl_its12_s = pd.concat([its12_s_200_reads_r,its12_s_250_reads_r,its12_s_300_reads_r,
                                      its12_s_500_reads_r,its12_s_1000_reads_r,its12_s_3000_reads_r,its12_s_5000_reads_r,
                                      its12_s_10000_reads_r,its12_s_30000_reads_r,its12_s_50000_reads_r,its12_s_100000_reads_r], axis = 1)

# %%
def get_color(obj_dict):
    color = ''
    while color not in obj_dict.values() and color == '':
        color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color
color_dict_its1_g = {}
color_dict_its1_s = {}
color_dict_its1_otu = {}
color_dict_its2_g = {}
color_dict_its2_s = {}
color_dict_its2_otu = {}
color_dict_its12_g = {}
color_dict_its12_s = {}
color_dict_its12_otu = {}

# %%
for taxon in mean_reampl_free_its1_g.index:
    color_dict_its1_g[taxon] = get_color(color_dict_its1_g)
for taxon in mean_reampl_free_its1_s.index:
    color_dict_its1_s[taxon] = get_color(color_dict_its1_s)
for taxon in mean_reampl_free_its1_otu.index:
    color_dict_its1_otu[taxon] = get_color(color_dict_its1_otu)
for taxon in mean_reampl_free_its2_g.index:
    color_dict_its2_g[taxon] = get_color(color_dict_its2_g)
for taxon in mean_reampl_free_its2_otu.index:
    color_dict_its2_otu[taxon] = get_color(color_dict_its2_otu)
for taxon in mean_reampl_free_its2_s.index:
    color_dict_its2_s[taxon] = get_color(color_dict_its2_s)
for taxon in mean_reampl_free_its12_g.index:
    color_dict_its12_g[taxon] = get_color(color_dict_its12_g)
for taxon in mean_reampl_free_its12_otu.index:
    color_dict_its12_otu[taxon] = get_color(color_dict_its12_otu)
for taxon in mean_reampl_free_its12_s.index:
    color_dict_its12_s[taxon] = get_color(color_dict_its12_s)

# %%
#colors_its1_g = plt.cm.tab20.colors[:len(mean_reampl_free_its1_g)]
#colors_its2_g = plt.cm.tab20.colors[:len(mean_reampl_free_its2_g)]
#colors_its12_g = plt.cm.tab20.colors[:len(mean_reampl_free_its12_g)]

# %%
fig, ax = plt.subplots(3,3, figsize=(20,12))

for i, row in enumerate(mean_reampl_free_its12_g.iterrows()):
    ax[0,0].plot(range(len(mean_reampl_free_its12_g.columns)), row[1], color=list(color_dict_its12_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_g.iterrows()):
    ax[0,0].plot(range(len(mean_reampl_its12_g.columns)), row[1], color=list(color_dict_its12_g.values())[i], linestyle = 'dashed')

ax[0,0].set_xlabel("Number of reads")
ax[0,0].set_ylabel("Relative abundance")
ax[0,0].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax[0,0].set_yscale('log')
ax[0,0].set_title('Genus ITS1_5.8_ITS2')
ax[0,0].legend(bbox_to_anchor=(1.525, 1.05), fontsize=6, title = 'Taxonomy')
ax[0,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its12_s.iterrows()):
    ax[0,1].plot(range(len(mean_reampl_free_its12_s.columns)), row[1], color=list(color_dict_its12_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_s.iterrows()):
    ax[0,1].plot(range(len(mean_reampl_its12_s.columns)), row[1], color=list(color_dict_its12_s.values())[i], linestyle = 'dashed')

ax[0,1].set_xlabel("Number of reads")
ax[0,1].set_ylabel("Relative abundance")
ax[0,1].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax.set_yscale('log')
ax[0,1].set_title('Species ITS1_5.8_ITS2')
ax[0,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[0,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its12_otu.iterrows()):
    ax[0,2].plot(range(len(mean_reampl_free_its12_otu.columns)), row[1], color=list(color_dict_its12_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_otu.iterrows()):
    ax[0,2].plot(range(len(mean_reampl_free_its12_otu.columns)), row[1], color=list(color_dict_its12_otu.values())[i], linestyle = 'dashed')

ax[0,2].set_xlabel("Number of reads")
ax[0,2].set_ylabel("Relative abundance")
ax[0,2].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax.set_yscale('log')
ax[0,2].set_title('OTU ITS1_5.8_ITS2')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[0,2].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_g.iterrows()):
    ax[1,0].plot(range(len(mean_reampl_free_its1_g.columns)), row[1], color=list(color_dict_its1_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_g.iterrows()):
    ax[1,0].plot(range(len(mean_reampl_its1_g.columns)), row[1], color=list(color_dict_its1_g.values())[i], linestyle = 'dashed')

ax[1,0].set_xlabel("Number of reads")
ax[1,0].set_ylabel("Relative abundance")
ax[1,0].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax[0,0].set_yscale('log')
ax[1,0].set_title('Genus ITS1')
ax[1,0].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6, title = 'Taxonomy')
ax[1,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its1_s.iterrows()):
    ax[1,1].plot(range(len(mean_reampl_free_its1_s.columns)), row[1], color=list(color_dict_its1_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_s.iterrows()):
    ax[1,1].plot(range(len(mean_reampl_its1_s.columns)), row[1], color=list(color_dict_its1_s.values())[i], linestyle = 'dashed')

ax[1,1].set_xlabel("Number of reads")
ax[1,1].set_ylabel("Relative abundance")
ax[1,1].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax.set_yscale('log')
ax[1,1].set_title('Species ITS1')
ax[1,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[1,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_otu.iterrows()):
    ax[1,2].plot(range(len(mean_reampl_free_its1_otu.columns)), row[1], color=list(color_dict_its1_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_otu.iterrows()):
    ax[1,2].plot(range(len(mean_reampl_free_its1_otu.columns)), row[1], color=list(color_dict_its1_otu.values())[i], linestyle = 'dashed')

ax[1,2].set_xlabel("Number of reads")
ax[1,2].set_ylabel("Relative abundance")
ax[1,2].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000',
                                                                             '100000'], rotation='vertical')
#ax.set_yscale('log')
ax[1,2].set_title('OTU ITS1')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[1,2].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_g.iterrows()):
    ax[2,0].plot(range(len(mean_reampl_free_its2_g.columns)), row[1], color=list(color_dict_its2_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_g.iterrows()):
    ax[2,0].plot(range(len(mean_reampl_its2_g.columns)), row[1], color=list(color_dict_its2_g.values())[i], linestyle = 'dashed')

ax[2,0].set_xlabel("Number of reads")
ax[2,0].set_ylabel("Relative abundance")
ax[2,0].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')
#ax[1,0].set_yscale('log')
ax[2,0].set_title('Genus ITS2')
ax[2,0].legend(bbox_to_anchor=(1.425, 1.05), fontsize=6,title = 'Taxonomy')
ax[2,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_s.iterrows()):
    ax[2,1].plot(range(len(mean_reampl_free_its2_s.columns)), row[1], color=list(color_dict_its2_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_s.iterrows()):
    ax[2,1].plot(range(len(mean_reampl_its2_s.columns)), row[1], color=list(color_dict_its2_s.values())[i], linestyle = 'dashed')

ax[2,1].set_xlabel("Number of reads")
ax[2,1].set_ylabel("Relative abundance")
ax[2,1].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')
#ax.set_yscale('log')
ax[2,1].set_title('Species ITS2')
ax[2,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[2,1].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_otu.iterrows()):
    ax[2,2].plot(range(len(mean_reampl_free_its2_otu.columns)), row[1], color=list(color_dict_its2_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_otu.iterrows()):
    ax[2,2].plot(range(len(mean_reampl_its2_otu.columns)), row[1], color=list(color_dict_its2_otu.values())[i], linestyle = 'dashed')

ax[2,2].set_xlabel("Number of reads")
ax[2,2].set_ylabel("Relative abundance")
ax[2,2].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns),1), labels = ['200','250','300','500',
                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')
#ax.set_yscale('log')
ax[2,2].set_title('OTU ITS2')
#ax[1,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[2,2].grid(alpha=0.7)

fig.show()
fig.tight_layout()
fig.savefig("ITSs_all_plots_abundance_vs_nreads_nolog_POOL_new_db.pdf",format="pdf", bbox_inches="tight")
fig.savefig("ITSs_all_plots_abundance_vs_nreads_nolog_POOL_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %% [markdown]
# **BARPLOTS**

# %%
#ITS1_reampl_s_data = pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_mode_k6_ITS1_300_3k_30k_data_tax_df_species.csv',sep ='\t', index_col=0)
ITS1_reampl_g_data = pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_mode_k6_ITS1_REAMPL_data_tax_df_genus.csv',sep ='\t', index_col=0)
ITS1_reampl_s_data = pd.read_csv('/home/sonec_iv/pike_ipynbs/pool_mode_k6_ITS1_REAMPL_data_tax_df_species.csv',sep ='\t', index_col=0)

# %%
ITS1_reampl_g_data

# %%
#ITS1_reampl_s_data
ITS1_reampl_g_data_sorted = ITS1_reampl_g_data.loc[ITS1_reampl_g_data.mean(axis=1).sort_values().index]
ITS1_reampl_g_data_sorted

# %%
ITS1_reampl_g_data_sort_Danil = ITS1_reampl_g_data.assign(m=ITS1_reampl_g_data.mean(axis=1)).sort_values('m').drop('m', axis=1)[np.sort(ITS1_reampl_g_data.columns)]
ITS1_reampl_g_data_sort_Danil

# %%
its1_s_30000_reads = ITS1_reampl_s_data.iloc[:,[0,3,6]].mean(axis=1)
its1_s_3000_reads = ITS1_reampl_s_data.iloc[:,[1,4,7]].mean(axis=1)
its1_s_300_reads = ITS1_reampl_s_data.iloc[:,[2,5,8]].mean(axis=1)
mean_reampl_its1_s = pd.concat([its1_s_300_reads,
                                      its1_s_3000_reads,its1_s_30000_reads], axis = 1)
its1_g_30000_reads = ITS1_reampl_g_data.iloc[:,[0,3,6]].mean(axis=1)
its1_g_3000_reads = ITS1_reampl_g_data.iloc[:,[1,4,7]].mean(axis=1)
its1_g_300_reads = ITS1_reampl_g_data.iloc[:,[2,5,8]].mean(axis=1)
mean_reampl_its1_g = pd.concat([its1_g_300_reads,
                                      its1_g_3000_reads,its1_g_30000_reads], axis = 1)

# %%
plt1 = ITS1_reampl_g_data.T.plot(kind='bar', stacked=True)
plt1.legend(bbox_to_anchor=(1.425, 1.05), fontsize=7, title = 'Taxonomy')

# %%
plt3 = ITS1_reampl_g_data_sort_Danil.T.plot(kind='bar', stacked=True)
plt3.legend(bbox_to_anchor=(1.425, 1.05), fontsize=7, title = 'Taxonomy')

# %%
data_its1_s_r = data_its1_s[[col for col in data_its1_s.columns if 'R' in col]]
data_its1_s_r

# %%
data_its1_s_rf = data_its1_s[[col for col in data_its1_s.columns if 'R' not in col]]
data_its1_s_rf

# %%
import re
def extract_key(column_name):
    match = re.match(r'(.+)_(\d+)_reads', column_name)
    if match:
        sample = match.group(1)
        n = int(match.group(2))
        return sample, n
    return column_name, float('inf')

# %%
sorted_columns = sorted(ITS1_reampl_g_data.columns, key=extract_key)
data_its1_g_r_sorted = ITS1_reampl_g_data[sorted_columns]
data_its1_s_r_sorted = ITS1_reampl_s_data[sorted_columns]

# %%
import plotly.express as px
import plotly.subplots as sp
fig = px.bar(data_its1_g_r_sorted.T, 
             y=data_its1_g_r_sorted.index, 
             x=data_its1_g_r_sorted.columns,
             width=1400, 
             height=1100, 
            # color=data_tax_df.index,
             labels={'value': 'Relative abundance', 'index':'Samples'}, 
             template='simple_white', title = 'ITS1 genus reamplificates')
            # color_discrete_map=Color_collection)
#fig.update_layout(yaxis_range=[0, 1], legend_title_text='Taxon', legend_title_side='top center')
fig.update_traces(marker_line_width=1.1, marker_line_color='#202020', opacity=0.8)
fig.update_yaxes(ticksuffix = "  ")
fig.show()
#fig.write_html("ITS1_species_reampl_sorted.html")

# %%
its12_coords = [200,250,300,500,1000,3000,5000,10000,30000,50000,100000]
its1_coords = [200,250,300,500,1000,3000,5000,10000,30000,50000,100000]
its2_coords = [200,250,300,500,1000,3000,5000,10000,30000,50000, 100000]

# %%
fig, ax = plt.subplots(3,3, figsize=(20,12))

for i, row in enumerate(mean_reampl_free_its12_g.iterrows()):
    ax[0,0].plot(its12_coords, row[1], color=list(color_dict_its12_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_g.iterrows()):
    ax[0,0].plot(its12_coords, row[1], color=list(color_dict_its12_g.values())[i], linestyle = 'dashed')

ax[0,0].set_xlabel("Number of reads")
ax[0,0].set_ylabel("Relative abundance")
#ax[0,0].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000'], rotation='vertical')
ax[0,0].set_xscale('log')
ax[0,0].set_title('Genus ITS1_5.8_ITS2')
ax[0,0].legend(bbox_to_anchor=(1.525, 1.05), fontsize=6, title = 'Taxonomy')
ax[0,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its12_s.iterrows()):
    ax[0,1].plot(its12_coords, row[1], color=list(color_dict_its12_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_s.iterrows()):
    ax[0,1].plot(its12_coords, row[1], color=list(color_dict_its12_s.values())[i], linestyle = 'dashed')

ax[0,1].set_xlabel("Number of reads")
ax[0,1].set_ylabel("Relative abundance")
#ax[0,1].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000'], rotation='vertical')
ax[0,1].set_xscale('log')
ax[0,1].set_title('Species ITS1_5.8_ITS2')
ax[0,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[0,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its12_otu.iterrows()):
    ax[0,2].plot(its12_coords, row[1], color=list(color_dict_its12_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its12_otu.iterrows()):
    ax[0,2].plot(its12_coords, row[1], color=list(color_dict_its12_otu.values())[i], linestyle = 'dashed')

ax[0,2].set_xlabel("Number of reads")
ax[0,2].set_ylabel("Relative abundance")
#ax[0,2].set_xticks(ticks = range(0,len(mean_reampl_free_its12_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000'], rotation='vertical')
ax[0,2].set_xscale('log')
ax[0,2].set_title('OTU ITS1_5.8_ITS2')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[0,2].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_g.iterrows()):
    ax[1,0].plot(its1_coords, row[1], color=list(color_dict_its1_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_g.iterrows()):
    ax[1,0].plot(its1_coords, row[1], color=list(color_dict_its1_g.values())[i], linestyle = 'dashed')

ax[1,0].set_xlabel("Number of reads")
ax[1,0].set_ylabel("Relative abundance")
#ax[1,0].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns)+1,1), labels = ['150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000','150000'], rotation='vertical')
ax[1,0].set_xscale('log')
ax[1,0].set_title('Genus ITS1')
ax[1,0].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6, title = 'Taxonomy')
ax[1,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its1_s.iterrows()):
    ax[1,1].plot(its1_coords, row[1], color=list(color_dict_its1_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_s.iterrows()):
    ax[1,1].plot(its1_coords, row[1], color=list(color_dict_its1_s.values())[i], linestyle = 'dashed')

ax[1,1].set_xlabel("Number of reads")
ax[1,1].set_ylabel("Relative abundance")
#ax[1,1].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns)+1,1), labels = ['150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000','150000'], rotation='vertical')
ax[1,1].set_xscale('log')
ax[1,1].set_title('Species ITS1')
ax[1,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[1,1].grid(alpha=0.7)


for i, row in enumerate(mean_reampl_free_its1_otu.iterrows()):
    ax[1,2].plot(its1_coords, row[1], color=list(color_dict_its1_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its1_otu.iterrows()):
    ax[1,2].plot(its1_coords, row[1], color=list(color_dict_its1_otu.values())[i], linestyle = 'dashed')

ax[1,2].set_xlabel("Number of reads")
ax[1,2].set_ylabel("Relative abundance")
#ax[1,2].set_xticks(ticks = range(0,len(mean_reampl_free_its1_g.columns)+1,1), labels = ['150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000',
#                                                                             '100000','150000'], rotation='vertical')
ax[1,2].set_xscale('log')
ax[1,2].set_title('OTU ITS1')
#ax[0,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[1,2].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_g.iterrows()):
    ax[2,0].plot(its2_coords, row[1], color=list(color_dict_its2_g.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_g.iterrows()):
    ax[2,0].plot(its2_coords, row[1], color=list(color_dict_its2_g.values())[i], linestyle = 'dashed')

ax[2,0].set_xlabel("Number of reads")
ax[2,0].set_ylabel("Relative abundance")
#ax[2,0].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')

ax[2,0].set_xscale('log')
ax[2,0].set_title('Genus ITS2')
ax[2,0].legend(bbox_to_anchor=(1.425, 1.05), fontsize=6,title = 'Taxonomy')
ax[2,0].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_s.iterrows()):
    ax[2,1].plot(its2_coords, row[1], color=list(color_dict_its2_s.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_s.iterrows()):
    ax[2,1].plot(its2_coords, row[1], color=list(color_dict_its2_s.values())[i], linestyle = 'dashed')

ax[2,1].set_xlabel("Number of reads")
ax[2,1].set_ylabel("Relative abundance")
#ax[2,1].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')
ax[2,1].set_xscale('log')
ax[2,1].set_title('Species ITS2')
ax[2,1].legend(bbox_to_anchor=(1.05, 1.05), fontsize=6,title = 'Taxonomy',ncols=2)
ax[2,1].grid(alpha=0.7)

for i, row in enumerate(mean_reampl_free_its2_otu.iterrows()):
    ax[2,2].plot(its2_coords, row[1], color=list(color_dict_its2_otu.values())[i], label=row[0], linestyle = 'solid')
for i, row in enumerate(mean_reampl_its2_otu.iterrows()):
    ax[2,2].plot(its2_coords, row[1], color=list(color_dict_its2_otu.values())[i], linestyle = 'dashed')

ax[2,2].set_xlabel("Number of reads")
ax[2,2].set_ylabel("Relative abundance")
#ax[2,2].set_xticks(ticks = range(0,len(mean_reampl_free_its2_g.columns)+1,1), labels = ['100','150','200','250','300','500',
#                                                                             '1000','3000','5000','10000','30000','50000','100000'], rotation='vertical')
ax[2,2].set_xscale('log')
ax[2,2].set_title('OTU ITS2')
#ax[1,2].legend(bbox_to_anchor=(1.05, 1.05), ncols=4)
ax[2,2].grid(alpha=0.7)

fig.show()
fig.tight_layout()
fig.savefig("ITSs_all_plots_abundance_vs_nreads_log_POOL_new_db.pdf",format="pdf", bbox_inches="tight")
fig.savefig("ITSs_all_plots_abundance_vs_nreads_log_POOL_new_db.png", dpi=800, format="png", bbox_inches='tight')
