# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import random
import numpy as np
import re
import plotly.express as px
import plotly.subplots as sp
import seaborn as sns

# %%
#pike_ipynbs/ITS_SINGLE_kmers_csvs/SINGLE_kmers_ITS_12_k6_data_tax_df_genus.csv
data_its1_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_OTU.csv',sep ='\t',index_col=0)
data_its1_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_genus.csv', sep='\t',index_col=0)
data_its1_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_species.csv', sep='\t',index_col=0)

data_its2_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_2_data_tax_df_OTU.csv', sep ='\t', index_col=0)
data_its2_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_2_data_tax_df_genus.csv', sep='\t',index_col=0)
data_its2_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_2_data_tax_df_species.csv', sep='\t',index_col=0)

data_its12_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_12_data_tax_df_OTU.csv', sep = '\t',index_col=0)
data_its12_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_12_data_tax_df_genus.csv', sep='\t',index_col=0)
data_its12_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_12_data_tax_df_species.csv', sep='\t',index_col=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #pike_ipynbs/ITS_SINGLE_kmers_csvs/SINGLE_kmers_ITS_12_k6_data_tax_df_genus.csv
# ----> 2 data_its1_otu =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_OTU.csv',sep ='\t',index_col=0)
#       3 data_its1_g =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_genus.csv', sep='\t',index_col=0)
#       4 data_its1_s =pd.read_csv('/home/sonec_iv/pike_ipynbs/ITS_diff_kmers_single/single_kmers_3_7_ITS_1_data_tax_df_species.csv', sep='\t',index_col=0)
#
# NameError: name 'pd' is not defined

# %%
def extract_key(column_name):
    match = re.match(r'(.+?)(?:_(\d+(?:\.\d+)?))?_reads', column_name)
    if match:
        sample = match.group(1)
        n = int(match.group(2))
        return sample, n
    return column_name, float('inf')

# %%
sorted_columns = sorted(data_its1_otu.columns, key=extract_key)
data_its1_otu_sorted = data_its1_otu[sorted_columns]
data_its1_g_sorted = data_its1_g[sorted_columns]
data_its1_s_sorted = data_its1_s[sorted_columns]

# %%
data_its1_otu.columns
# Out:
# Index(['ITS1_1_3_kmer_size', 'ITS1_1_4_kmer_size', 'ITS1_1_5_kmer_size',
#        'ITS1_1_6_kmer_size', 'ITS1_1_7_kmer_size', 'ITS1_2_3_kmer_size',
#        'ITS1_2_4_kmer_size', 'ITS1_2_5_kmer_size', 'ITS1_2_6_kmer_size',
#        'ITS1_2_7_kmer_size', 'ITS1_3_3_kmer_size', 'ITS1_3_4_kmer_size',
#        'ITS1_3_5_kmer_size', 'ITS1_3_6_kmer_size', 'ITS1_3_7_kmer_size',
#        'ITS1_R1_3_kmer_size', 'ITS1_R1_4_kmer_size', 'ITS1_R1_5_kmer_size',
#        'ITS1_R1_6_kmer_size', 'ITS1_R1_7_kmer_size', 'ITS1_R2_3_kmer_size',
#        'ITS1_R2_4_kmer_size', 'ITS1_R2_5_kmer_size', 'ITS1_R2_6_kmer_size',
#        'ITS1_R2_7_kmer_size', 'ITS1_R3_3_kmer_size', 'ITS1_R3_4_kmer_size',
#        'ITS1_R3_5_kmer_size', 'ITS1_R3_6_kmer_size', 'ITS1_R3_7_kmer_size'],
#       dtype='object')

# %%
sorted_columns2 = sorted(data_its2_otu.columns, key=extract_key)
data_its2_otu_sorted = data_its2_otu[sorted_columns2]
data_its2_g_sorted = data_its2_g[sorted_columns2]
data_its2_s_sorted = data_its2_s[sorted_columns2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sorted_columns2 = sorted(data_its2_otu.columns, key=extract_key)
#       2 data_its2_otu_sorted = data_its2_otu[sorted_columns2]
#       3 data_its2_g_sorted = data_its2_g[sorted_columns2]
#
# NameError: name 'extract_key' is not defined

# %%
sorted_columns3 = sorted(data_its12_otu.columns, key=extract_key)
data_its12_otu_sorted = data_its12_otu[sorted_columns3]
data_its12_g_sorted = data_its12_g[sorted_columns3]
data_its12_s_sorted = data_its12_s[sorted_columns3]

# %%
fig = px.bar(data_its1_g_sorted.T, 
             y=data_its1_g_sorted.index, 
             x=data_its1_g_sorted.columns,
             width=1000, 
             height=1000, 
            # color=data_tax_df.index,
             labels={'value': 'Relative abundance', 'index':'Samples'}, 
             template='simple_white', title = 'ITS1 genus')
            # color_discrete_map=Color_collection)
#fig.update_layout(yaxis_range=[0, 1], legend_title_text='Taxon', legend_title_side='top center')
fig.update_traces(marker_line_width=1.1, marker_line_color='#202020', opacity=0.8)
fig.update_yaxes(ticksuffix = "  ")
fig.show()

# %%
number_mapping = {col: int(col.split('_')[-3]) for col in data_its1_g.columns}
number_mapping
# Out:
# {'ITS1_1_3_kmer_size': 3,
#  'ITS1_1_4_kmer_size': 4,
#  'ITS1_1_5_kmer_size': 5,
#  'ITS1_1_6_kmer_size': 6,
#  'ITS1_1_7_kmer_size': 7,
#  'ITS1_2_3_kmer_size': 3,
#  'ITS1_2_4_kmer_size': 4,
#  'ITS1_2_5_kmer_size': 5,
#  'ITS1_2_6_kmer_size': 6,
#  'ITS1_2_7_kmer_size': 7,
#  'ITS1_3_3_kmer_size': 3,
#  'ITS1_3_4_kmer_size': 4,
#  'ITS1_3_5_kmer_size': 5,
#  'ITS1_3_6_kmer_size': 6,
#  'ITS1_3_7_kmer_size': 7,
#  'ITS1_R1_3_kmer_size': 3,
#  'ITS1_R1_4_kmer_size': 4,
#  'ITS1_R1_5_kmer_size': 5,
#  'ITS1_R1_6_kmer_size': 6,
#  'ITS1_R1_7_kmer_size': 7,
#  'ITS1_R2_3_kmer_size': 3,
#  'ITS1_R2_4_kmer_size': 4,
#  'ITS1_R2_5_kmer_size': 5,
#  'ITS1_R2_6_kmer_size': 6,
#  'ITS1_R2_7_kmer_size': 7,
#  'ITS1_R3_3_kmer_size': 3,
#  'ITS1_R3_4_kmer_size': 4,
#  'ITS1_R3_5_kmer_size': 5,
#  'ITS1_R3_6_kmer_size': 6,
#  'ITS1_R3_7_kmer_size': 7}

# %%
number_mapping = {col: int(col.split('_')[-3]) for col in data_its1_g.columns}
sorted_columns = sorted(number_mapping, key=number_mapping.get)
data_its1_g_sorted = data_its1_g[sorted_columns]
data_its1_s_sorted = data_its1_s[sorted_columns]
data_its1_otu_sorted = data_its1_otu[sorted_columns]

# %%
number_mapping2 = {col: int(col.split('_')[-3]) for col in data_its2_g.columns}
sorted_columns2 = sorted(number_mapping2, key=number_mapping2.get)
data_its2_g_sorted = data_its2_g[sorted_columns2]
data_its2_s_sorted = data_its2_s[sorted_columns2]
data_its2_otu_sorted = data_its2_otu[sorted_columns2]

# %%
number_mapping3 = {col: int(col.split('_')[-3]) for col in data_its12_g.columns}
sorted_columns3 = sorted(number_mapping3, key=number_mapping3.get)
data_its12_g_sorted = data_its12_g[sorted_columns3]
data_its12_s_sorted = data_its12_s[sorted_columns3]
data_its12_otu_sorted = data_its12_otu[sorted_columns3]

# %%
for column in data_its1_otu_sorted.columns: 
    data_its1_otu_sorted[column] = data_its1_otu_sorted[column]/data_its1_otu_sorted[column].sum()
for column in data_its2_otu_sorted.columns: 
    data_its2_otu_sorted[column] = data_its2_otu_sorted[column]/data_its2_otu_sorted[column].sum()
for column in data_its12_otu_sorted.columns: 
    data_its12_otu_sorted[column] = data_its12_otu_sorted[column]/data_its12_otu_sorted[column].sum()

# %%
number_mapping
# Out:
# {'ITS1_1_3_kmer_size': 3,
#  'ITS1_1_4_kmer_size': 4,
#  'ITS1_1_5_kmer_size': 5,
#  'ITS1_1_6_kmer_size': 6,
#  'ITS1_1_7_kmer_size': 7,
#  'ITS1_2_3_kmer_size': 3,
#  'ITS1_2_4_kmer_size': 4,
#  'ITS1_2_5_kmer_size': 5,
#  'ITS1_2_6_kmer_size': 6,
#  'ITS1_2_7_kmer_size': 7,
#  'ITS1_3_3_kmer_size': 3,
#  'ITS1_3_4_kmer_size': 4,
#  'ITS1_3_5_kmer_size': 5,
#  'ITS1_3_6_kmer_size': 6,
#  'ITS1_3_7_kmer_size': 7,
#  'ITS1_R1_3_kmer_size': 3,
#  'ITS1_R1_4_kmer_size': 4,
#  'ITS1_R1_5_kmer_size': 5,
#  'ITS1_R1_6_kmer_size': 6,
#  'ITS1_R1_7_kmer_size': 7,
#  'ITS1_R2_3_kmer_size': 3,
#  'ITS1_R2_4_kmer_size': 4,
#  'ITS1_R2_5_kmer_size': 5,
#  'ITS1_R2_6_kmer_size': 6,
#  'ITS1_R2_7_kmer_size': 7,
#  'ITS1_R3_3_kmer_size': 3,
#  'ITS1_R3_4_kmer_size': 4,
#  'ITS1_R3_5_kmer_size': 5,
#  'ITS1_R3_6_kmer_size': 6,
#  'ITS1_R3_7_kmer_size': 7}

# %%
data_its1_g_sorted

# %%
def get_color(obj_dict):
    color = ''
    while color not in obj_dict.values() and color == '':  
        color = "#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
    return color
color_collection_its1_g = {}
color_collection_its1_s = {}
color_collection_its1_otu = {}
color_collection_its2_g = {}
color_collection_its2_s = {}
color_collection_its2_otu = {}
color_collection_its12_g = {}
color_collection_its12_s = {}
color_collection_its12_otu = {}

# %%
for i in data_its1_g_sorted.index:
    color_collection_its1_g[i] = get_color(color_collection_its1_g)
for i in data_its1_s_sorted.index:
    color_collection_its1_s[i] = get_color(color_collection_its1_s)
for i in data_its1_otu_sorted.index:
    color_collection_its1_otu[i] = get_color(color_collection_its1_otu)
for i in data_its2_g_sorted.index:
    color_collection_its2_g[i] = get_color(color_collection_its2_g)
for i in data_its2_s_sorted.index:
    color_collection_its2_s[i] = get_color(color_collection_its2_s)
for i in data_its2_otu_sorted.index:
    color_collection_its2_otu[i] = get_color(color_collection_its2_otu)
for i in data_its12_g_sorted.index:
    color_collection_its12_g[i] = get_color(color_collection_its12_g)
for i in data_its12_s_sorted.index:
    color_collection_its12_s[i] = get_color(color_collection_its12_s)
for i in data_its12_otu_sorted.index:
    color_collection_its12_otu[i] = get_color(color_collection_its12_otu)

# %%
data_its1_g.index

# %%
color_collection

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_g_sorted.columns:
    for genus in data_its1_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_g[genus])
        bottom += data_its1_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its1_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 Genus diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS1_genus_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS1_genus_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')
#plt.tight_layout()

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_s_sorted.columns:
    for genus in data_its1_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_s[genus])
        bottom += data_its1_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its1_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 Species diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS1_species_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS1_species_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_g_sorted.columns:
    for genus in data_its2_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_g[genus])
        bottom += data_its2_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its2_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 Genus diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS2_genus_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS2_genus_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_s_sorted.columns:
    for genus in data_its2_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_s[genus])
        bottom += data_its2_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its2_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 Species diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS2_species_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS2_species_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_g_sorted.columns:
    for genus in data_its12_g_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_g_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_g[genus])
        bottom += data_its12_g_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_g_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_g_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_g.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 Genus diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_genus_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_genus_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_s_sorted.columns:
    for genus in data_its12_s_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_s_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_s[genus])
        bottom += data_its12_s_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_s_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_s_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 diff k-mers Species single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_species_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_species_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its12_otu_sorted.columns:
    for genus in data_its12_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its12_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its12_otu[genus])
        bottom += data_its12_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its12_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1_5.8_ITS2 OTU diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_full_OTU_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_full_OTU_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its1_otu_sorted.columns:
    for genus in data_its1_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its1_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its1_otu[genus])
        bottom += data_its1_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its1_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']
while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its12_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS1 OTU diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_1_OTU_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_1_OTU_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')

# %%
sample_coord = 0
sample_coords_list = []
counter = 0
width = 1
bottom = 0
#plt.rcParams["figure.figsize"] = (12, 12)
plt.figure(figsize=(20, 12))
for sample in data_its2_otu_sorted.columns:
    for genus in data_its2_otu_sorted.index:
        plt.bar(sample_coord, 
                    data_its2_otu_sorted[sample][genus], 
                    width,  
                    bottom=bottom,
                    label = genus,
                    edgecolor='black',
                    linewidth=0.4, 
                    alpha=0.7,
                    color=color_collection_its2_otu[genus])
        bottom += data_its2_otu_sorted[sample][genus]
    sample_coords_list.append(sample_coord)
    sample_coord += 1
    counter +=1
    if counter % 6 == 0:
        sample_coords_list.append(sample_coord)
        sample_coord += 1.5
        counter = 0
    bottom = 0

new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_otu_sorted.columns, rotation = 'vertical')
sns.despine(offset=10, trim=True)
plt.xlabel("Sample", fontsize = 16)
plt.ylim(top=1.15)
new_list = [item for index, item in enumerate(sample_coords_list) if (index + 1) % 7 != 0]
plt.xticks(ticks = new_list, labels = data_its2_otu_sorted.columns, rotation = 'vertical')

y = 1.02 
str_length = 6  
gap_btw = 1.5  
max_x = 102.5 
x_start = -0.5
x_values = []
hline_labels = ['k-mer = 3','k-mer = 4', 'k-mer = 5', 'k-mer = 6', 'k-mer = 7']

while x_start <= max_x:
    x_values.append((x_start, x_start + str_length))  
    x_start += str_length + gap_btw 

for (start, end), labels in zip(x_values, hline_labels):
    plt.hlines(y, start, end, color='black')
    plt.text((start + end) / 2, y + 0.01, labels, ha='center')
#patches = [mpatches.Patch(color=color, label=genus) for genus, color in color_collection_its22_s.items()]
plt.ylabel("Relative abundance", fontsize = 16)
#plt.legend(handles = patches,title='Taxon',bbox_to_anchor = (1.1,0.75))
plt.title('ITS2 OTU diff k-mers single mode', loc = 'center', fontsize = 16)
plt.savefig("ITS_2_OTU_abundance_SINGLE_kmers_new_db.pdf",format="pdf", bbox_inches="tight")
plt.savefig("ITS_2_OTU_abundance_SINGLE_kmers_new_db.png", dpi=800, format="png", bbox_inches='tight')
